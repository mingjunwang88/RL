# %%
import ray
from ray.rllib.agents import ppo, ddpg, sac
from ray import tune 
from supplychain import SimpleSupplyChain
import importlib
#importlib.reload(supplychain)

# %%
ray.shutdown()
ray.init()
# Out:
# 2022-04-21 13:18:08,057	INFO services.py:1462 -- View the Ray dashboard at http://127.0.0.1:8265
# RayContext(dashboard_url='127.0.0.1:8265', python_version='3.6.13', ray_version='1.12.0', ray_commit='f18fc31c7562990955556899090f8e8656b48d2d', address_info={'node_ip_address': '172.16.30.231', 'raylet_ip_address': '172.16.30.231', 'redis_address': None, 'object_store_address': '/tmp/ray/session_2022-04-21_13-18-05_187419_65436/sockets/plasma_store', 'raylet_socket_name': '/tmp/ray/session_2022-04-21_13-18-05_187419_65436/sockets/raylet', 'webui_url': '127.0.0.1:8265', 'session_dir': '/tmp/ray/session_2022-04-21_13-18-05_187419_65436', 'metrics_export_port': 57843, 'gcs_address': '172.16.30.231:64966', 'address': '172.16.30.231:64966', 'node_id': '8dc7f5be4bfe1f406934b329ce92cda7370448b5b72d7915a3cc5c58'})

# %%
alg = 'DDPG'
tune.run(alg,
    stop={"training_iteration": 100},
    config={
        'env':SimpleSupplyChain,
        'num_gpus':0,
        'num_workers':2,
        'lr':tune.grid_search([.001,])     
    }
)
# Out:
# 2022-04-21 13:19:05,150	INFO trial_runner.py:803 -- starting DDPG_SimpleSupplyChain_9cd27_00000
# (DDPGTrainer pid=71982) 2022-04-21 13:19:13,059	INFO trainer.py:2296 -- Your framework setting is 'tf', meaning you are using static-graph mode. Set framework='tf2' to enable eager execution with tf2.x. You may also then want to set eager_tracing=True in order to reach similar execution speed as with static-graph mode.
# (DDPGTrainer pid=71982) 2022-04-21 13:19:13,060	INFO simple_q.py:162 -- In multi-agent mode, policies will be optimized sequentially by the multi-GPU optimizer. Consider setting `simple_optimizer=True` if this doesn't work for you.
# (DDPGTrainer pid=71982) 2022-04-21 13:19:13,060	INFO trainer.py:867 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# (RolloutWorker pid=72172) 2022-04-21 13:19:19,232	WARNING rollout_worker.py:499 -- We've added a module for checking environments that are used in experiments. It will cause your environment to fail if your environment is not set upcorrectly. You can disable check env by setting `disable_env_checking` to True in your experiment config dictionary. You can run the environment checking module standalone by calling ray.rllib.utils.check_env(env).
# (RolloutWorker pid=72172) 2022-04-21 13:19:19,232	WARNING env.py:121 -- Your env doesn't have a .spec.max_episode_steps attribute. This is fine if you have set 'horizon' in your config dictionary, or `soft_horizon`. However, if you haven't, 'horizon' will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=72163) 2022-04-21 13:19:19,171	WARNING rollout_worker.py:499 -- We've added a module for checking environments that are used in experiments. It will cause your environment to fail if your environment is not set upcorrectly. You can disable check env by setting `disable_env_checking` to True in your experiment config dictionary. You can run the environment checking module standalone by calling ray.rllib.utils.check_env(env).
# (RolloutWorker pid=72163) 2022-04-21 13:19:19,171	WARNING env.py:121 -- Your env doesn't have a .spec.max_episode_steps attribute. This is fine if you have set 'horizon' in your config dictionary, or `soft_horizon`. However, if you haven't, 'horizon' will default to infinity, and your environment will not be reset.
# == Status ==<br>Current time: 2022-04-21 13:19:22 (running for 00:00:17.88)<br>Memory usage on this node: 17.3/720.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3.0/64 CPUs, 0/16 GPUs, 0.0/516.84 GiB heap, 0.0/186.26 GiB objects (0.0/1.0 accelerator_type:K80)<br>Result logdir: /home/ec2-user/ray_results/DDPG<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                        </th><th>status  </th><th>loc                </th><th style="text-align: right;">   lr</th></tr>
# </thead>
# <tbody>
# <tr><td>DDPG_SimpleSupplyChain_9cd27_00000</td><td>RUNNING </td><td>172.16.30.231:71982</td><td style="text-align: right;">0.001</td></tr>
# </tbody>
# </table><br><br>
# (DDPGTrainer pid=71982) 2022-04-21 13:19:22,702	WARNING util.py:60 -- Install gputil for GPU system monitoring.
# Result for DDPG_SimpleSupplyChain_9cd27_00000:
#   agent_timesteps_total: 1500
#   custom_metrics: {}
#   date: 2022-04-21_13-19-26
#   done: false
#   episode_len_mean: 25.0
#   episode_media: {}
#   episode_reward_max: -1158249.2456297167
#   episode_reward_mean: -1208774.5500992064
#   episode_reward_min: -1241061.3487362154
#   episodes_this_iter: 60
#   episodes_total: 60
#   experiment_id: 9f81eda9c1254e3cb231c759aaf54cbb
#   hostname: ip-172-16-30-231
#   info:
#     last_target_update_ts: 1500
#     learner:
#       default_policy:
#         custom_metrics: {}
#         learner_stats:
#           max_q: 46.93806076049805
#           mean_q: 20.710132598876953
#           min_q: 0.18513096868991852
#           model: {}
#         num_agent_steps_trained: 256.0
#         td_error:
#         - 56305.859375
#         - 87929.8359375
#         - 87546.984375
#         - 56042.88671875
#         - 3960.681884765625
#         - 74360.6484375
#         - 71961.40625
#         - 29206.6484375
#         - 79877.015625
#         - 35030.50390625
#         - 78906.0859375
#         - 25457.46875
#         - 20698.572265625
#         - 95785.71875
#         - 89998.1796875
#         - -149.82855224609375
#         - 24914.517578125
#         - 81605.484375
#         - 76889.6640625
#         - 55655.5703125
#         - 67204.8203125
#         - 13287.7685546875
#         - 60034.671875
#         - 73707.796875
#         - 8753.830078125
#         - 95855.1328125
#         - 36302.390625
#         - 84298.8984375
#         - 80247.5546875
#         - 96365.6875
#         - 88119.1328125
#         - 72036.3984375
#         - 150.60894775390625
#         - 13056.890625
#         - 46133.29296875
#         - 73665.2265625
#         - 66071.8125
#         - 17583.38671875
#         - 88597.875
#         - 92869.671875
#         - 25191.857421875
#         - 87247.578125
#         - 21173.341796875
#         - 59881.84375
#         - 28386.98828125
#         - 87546.984375
#         - 95568.9140625
#         - 35838.6171875
#         - 25757.521484375
#         - 80073.703125
#         - 17111.55078125
#         - 77449.90625
#         - 16892.873046875
#         - 94505.609375
#         - 26366.279296875
#         - 13057.8095703125
#         - 47735.96875
#         - 78906.0859375
#         - 47696.9609375
#         - 20747.322265625
#         - 88162.65625
#         - 48282.75390625
#         - 47403.4296875
#         - 29668.6015625
#         - 42858.7890625
#         - 74360.6484375
#         - 87200.2578125
#         - 73521.8125
#         - 44632.06640625
#         - 84966.4921875
#         - 84370.265625
#         - 31217.68359375
#         - 37674.1640625
#         - 51898.06640625
#         - 13357.2333984375
#         - 83886.4296875
#         - 64345.46484375
#         - 40026.078125
#         - 4573.6875
#         - 86081.140625
#         - 81205.4765625
#         - 17282.87109375
#         - 29482.787109375
#         - 17283.404296875
#         - 21300.451171875
#         - 84945.4765625
#         - 56441.09765625
#         - 21856.087890625
#         - 56282.83984375
#         - 51977.45703125
#         - 4573.6875
#         - 88573.2890625
#         - 53145.25390625
#         - 38550.60546875
#         - 42875.39453125
#         - 55038.6171875
#         - 73427.1875
#         - 95071.75
#         - 21502.162109375
#         - 48535.5703125
#         - 96532.921875
#         - 65417.61328125
#         - 13325.36328125
#         - 89975.8828125
#         - 9040.087890625
#         - 73757.09375
#         - 40518.61328125
#         - 63891.046875
#         - 27268.30078125
#         - 90134.1484375
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 2.9333333333333336
#     ram_util_percent: 2.4
#   pid: 71982
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.1593409143338667
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.30699138158805833
#     mean_inference_ms: 1.0435589143979087
#     mean_raw_obs_processing_ms: 0.4341854712617065
#   time_since_restore: 3.8253917694091797
#   time_this_iter_s: 3.8253917694091797
#   time_total_s: 3.8253917694091797
#   timers:
#     learn_throughput: 1274.637
#     learn_time_ms: 200.841
#     load_throughput: 1043480.879
#     load_time_ms: 0.245
#     update_time_ms: 4.915
#   timestamp: 1650547166
#   timesteps_since_restore: 256
#   timesteps_this_iter: 256
#   timesteps_total: 1500
#   training_iteration: 1
#   trial_id: 9cd27_00000
#   warmup_time: 9.651880264282227
# == Status ==<br>Current time: 2022-04-21 13:19:26 (running for 00:00:21.79)<br>Memory usage on this node: 17.3/720.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3.0/64 CPUs, 0/16 GPUs, 0.0/516.84 GiB heap, 0.0/186.26 GiB objects (0.0/1.0 accelerator_type:K80)<br>Result logdir: /home/ec2-user/ray_results/DDPG<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                        </th><th>status  </th><th>loc                </th><th style="text-align: right;">   lr</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  ts</th><th style="text-align: right;">      reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>DDPG_SimpleSupplyChain_9cd27_00000</td><td>RUNNING </td><td>172.16.30.231:71982</td><td style="text-align: right;">0.001</td><td style="text-align: right;">     1</td><td style="text-align: right;">         3.82539</td><td style="text-align: right;">1500</td><td style="text-align: right;">-1.20877e+06</td><td style="text-align: right;">        -1.15825e+06</td><td style="text-align: right;">        -1.24106e+06</td><td style="text-align: right;">                25</td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-21 13:19:31 (running for 00:00:26.80)<br>Memory usage on this node: 17.4/720.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3.0/64 CPUs, 0/16 GPUs, 0.0/516.84 GiB heap, 0.0/186.26 GiB objects (0.0/1.0 accelerator_type:K80)<br>Result logdir: /home/ec2-user/ray_results/DDPG<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                        </th><th>status  </th><th>loc                </th><th style="text-align: right;">   lr</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  ts</th><th style="text-align: right;">      reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>DDPG_SimpleSupplyChain_9cd27_00000</td><td>RUNNING </td><td>172.16.30.231:71982</td><td style="text-align: right;">0.001</td><td style="text-align: right;">     1</td><td style="text-align: right;">         3.82539</td><td style="text-align: right;">1500</td><td style="text-align: right;">-1.20877e+06</td><td style="text-align: right;">        -1.15825e+06</td><td style="text-align: right;">        -1.24106e+06</td><td style="text-align: right;">                25</td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-21 13:19:36 (running for 00:00:31.81)<br>Memory usage on this node: 17.4/720.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3.0/64 CPUs, 0/16 GPUs, 0.0/516.84 GiB heap, 0.0/186.26 GiB objects (0.0/1.0 accelerator_type:K80)<br>Result logdir: /home/ec2-user/ray_results/DDPG<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                        </th><th>status  </th><th>loc                </th><th style="text-align: right;">   lr</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  ts</th><th style="text-align: right;">      reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>DDPG_SimpleSupplyChain_9cd27_00000</td><td>RUNNING </td><td>172.16.30.231:71982</td><td style="text-align: right;">0.001</td><td style="text-align: right;">     1</td><td style="text-align: right;">         3.82539</td><td style="text-align: right;">1500</td><td style="text-align: right;">-1.20877e+06</td><td style="text-align: right;">        -1.15825e+06</td><td style="text-align: right;">        -1.24106e+06</td><td style="text-align: right;">                25</td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-21 13:19:41 (running for 00:00:36.81)<br>Memory usage on this node: 17.4/720.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3.0/64 CPUs, 0/16 GPUs, 0.0/516.84 GiB heap, 0.0/186.26 GiB objects (0.0/1.0 accelerator_type:K80)<br>Result logdir: /home/ec2-user/ray_results/DDPG<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                        </th><th>status  </th><th>loc                </th><th style="text-align: right;">   lr</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  ts</th><th style="text-align: right;">      reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>DDPG_SimpleSupplyChain_9cd27_00000</td><td>RUNNING </td><td>172.16.30.231:71982</td><td style="text-align: right;">0.001</td><td style="text-align: right;">     1</td><td style="text-align: right;">         3.82539</td><td style="text-align: right;">1500</td><td style="text-align: right;">-1.20877e+06</td><td style="text-align: right;">        -1.15825e+06</td><td style="text-align: right;">        -1.24106e+06</td><td style="text-align: right;">                25</td></tr>
# </tbody>
# </table><br><br>
# Result for DDPG_SimpleSupplyChain_9cd27_00000:
#   agent_timesteps_total: 2500
#   custom_metrics: {}
#   date: 2022-04-21_13-19-42
#   done: false
#   episode_len_mean: 25.0
#   episode_media: {}
#   episode_reward_max: -472478.36308043066
#   episode_reward_mean: -1081624.6692544417
#   episode_reward_min: -1296917.5591549166
#   episodes_this_iter: 40
#   episodes_total: 100
#   experiment_id: 9f81eda9c1254e3cb231c759aaf54cbb
#   hostname: ip-172-16-30-231
#   info:
#     last_target_update_ts: 2500
#     learner:
#       default_policy:
#         custom_metrics: {}
#         learner_stats:
#           max_q: -54.903079986572266
#           mean_q: -57006.05078125
#           min_q: -123708.390625
#           model: {}
#         num_agent_steps_trained: 256.0
#         td_error:
#         - 2034.0234375
#         - 1280.2421875
#         - -522.869140625
#         - -1291.6015625
#         - 996.9281616210938
#         - -472.05859375
#         - 791.984375
#         - 5251.8828125
#         - -911.537109375
#         - 644.650390625
#         - 1279.79931640625
#         - -44.4609375
#         - 0.0078125
#         - -1147.439453125
#         - 381.041015625
#         - -1185.388671875
#         - 567.4296875
#         - -485.359375
#         - 4289.1015625
#         - -697.09375
#         - -894.0
#         - 116.10546875
#         - -289.29296875
#         - 246.99609375
#         - -663.984375
#         - -24650.5546875
#         - 1360.013916015625
#         - -151.046875
#         - 636.1953125
#         - -846.5703125
#         - -19926.6328125
#         - 6928.359375
#         - 499.4052734375
#         - -168.365234375
#         - 632.4442138671875
#         - -1360.734375
#         - 226.69140625
#         - 443.2060546875
#         - -24297.921875
#         - 3963.609375
#         - -1089.7734375
#         - 91.2109375
#         - 3503.1328125
#         - 381.041015625
#         - -666.662109375
#         - 212.67578125
#         - 24.6953125
#         - 1517.46875
#         - -90.3359375
#         - 763.56640625
#         - -898.7421875
#         - -1033.30078125
#         - -1456.05859375
#         - 41.01171875
#         - -1138.26953125
#         - -838.21875
#         - 3416.71875
#         - -224.1328125
#         - 1167.375
#         - 553.09375
#         - -1075.9765625
#         - 1273.5546875
#         - 3416.71875
#         - 261.6171875
#         - -198.3203125
#         - -320.046875
#         - -916.203125
#         - -534.45703125
#         - 2731.859375
#         - -689.328125
#         - -25084.6796875
#         - -1386.171875
#         - -129.5625
#         - -659.22265625
#         - 1568.3203125
#         - 372.32421875
#         - -1130.61328125
#         - -887.34765625
#         - -147.359375
#         - -272.412109375
#         - -400.44921875
#         - -1287.1484375
#         - -622.21875
#         - -988.1953125
#         - 427.35693359375
#         - 486.609375
#         - -472.24609375
#         - -799.0703125
#         - 461.765625
#         - 559.0625
#         - 248.6953125
#         - 6493.1015625
#         - 7214.3828125
#         - 59.7998046875
#         - 292.0263671875
#         - 4430.671875
#         - -882.31640625
#         - -80.2041015625
#         - 981.79296875
#         - -1146.177734375
#         - 135.25390625
#         - -673.15625
#         - 293.13330078125
#         - -961.341796875
#         - -405.5859375
#     num_agent_steps_sampled: 2500
#     num_agent_steps_trained: 128256
#     num_steps_sampled: 2500
#     num_steps_trained: 128256
#     num_steps_trained_this_iter: 256
#     num_target_updates: 501
#   iterations_since_restore: 2
#   node_ip: 172.16.30.231
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 3.7086956521739123
#     ram_util_percent: 2.3999999999999995
#   pid: 71982
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.16032743612282158
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.30947839878886074
#     mean_inference_ms: 1.0439056474753599
#     mean_raw_obs_processing_ms: 0.43651161103444097
#   time_since_restore: 19.926674365997314
#   time_this_iter_s: 16.101282596588135
#   time_total_s: 19.926674365997314
#   timers:
#     learn_throughput: 44537.34
#     learn_time_ms: 5.748
#     load_throughput: 1254371.29
#     load_time_ms: 0.204
#     update_time_ms: 2.853
#   timestamp: 1650547182
#   timesteps_since_restore: 512
#   timesteps_this_iter: 256
#   timesteps_total: 2500
#   training_iteration: 2
#   trial_id: 9cd27_00000
#   warmup_time: 9.651880264282227
# == Status ==<br>Current time: 2022-04-21 13:19:47 (running for 00:00:42.95)<br>Memory usage on this node: 17.4/720.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3.0/64 CPUs, 0/16 GPUs, 0.0/516.84 GiB heap, 0.0/186.26 GiB objects (0.0/1.0 accelerator_type:K80)<br>Result logdir: /home/ec2-user/ray_results/DDPG<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                        </th><th>status  </th><th>loc                </th><th style="text-align: right;">   lr</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  ts</th><th style="text-align: right;">      reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>DDPG_SimpleSupplyChain_9cd27_00000</td><td>RUNNING </td><td>172.16.30.231:71982</td><td style="text-align: right;">0.001</td><td style="text-align: right;">     2</td><td style="text-align: right;">         19.9267</td><td style="text-align: right;">2500</td><td style="text-align: right;">-1.08162e+06</td><td style="text-align: right;">             -472478</td><td style="text-align: right;">        -1.29692e+06</td><td style="text-align: right;">                25</td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-21 13:19:52 (running for 00:00:47.95)<br>Memory usage on this node: 17.4/720.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3.0/64 CPUs, 0/16 GPUs, 0.0/516.84 GiB heap, 0.0/186.26 GiB objects (0.0/1.0 accelerator_type:K80)<br>Result logdir: /home/ec2-user/ray_results/DDPG<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                        </th><th>status  </th><th>loc                </th><th style="text-align: right;">   lr</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  ts</th><th style="text-align: right;">      reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>DDPG_SimpleSupplyChain_9cd27_00000</td><td>RUNNING </td><td>172.16.30.231:71982</td><td style="text-align: right;">0.001</td><td style="text-align: right;">     2</td><td style="text-align: right;">         19.9267</td><td style="text-align: right;">2500</td><td style="text-align: right;">-1.08162e+06</td><td style="text-align: right;">             -472478</td><td style="text-align: right;">        -1.29692e+06</td><td style="text-align: right;">                25</td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-21 13:19:57 (running for 00:00:52.96)<br>Memory usage on this node: 17.4/720.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3.0/64 CPUs, 0/16 GPUs, 0.0/516.84 GiB heap, 0.0/186.26 GiB objects (0.0/1.0 accelerator_type:K80)<br>Result logdir: /home/ec2-user/ray_results/DDPG<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                        </th><th>status  </th><th>loc                </th><th style="text-align: right;">   lr</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  ts</th><th style="text-align: right;">      reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>DDPG_SimpleSupplyChain_9cd27_00000</td><td>RUNNING </td><td>172.16.30.231:71982</td><td style="text-align: right;">0.001</td><td style="text-align: right;">     2</td><td style="text-align: right;">         19.9267</td><td style="text-align: right;">2500</td><td style="text-align: right;">-1.08162e+06</td><td style="text-align: right;">             -472478</td><td style="text-align: right;">        -1.29692e+06</td><td style="text-align: right;">                25</td></tr>
# </tbody>
# </table><br><br>
# Result for DDPG_SimpleSupplyChain_9cd27_00000:
#   agent_timesteps_total: 3500
#   custom_metrics: {}
#   date: 2022-04-21_13-19-58
#   done: false
#   episode_len_mean: 25.0
#   episode_media: {}
#   episode_reward_max: -472478.36308043066
#   episode_reward_mean: -919873.7142457158
#   episode_reward_min: -1296917.5591549166
#   episodes_this_iter: 40
#   episodes_total: 140
#   experiment_id: 9f81eda9c1254e3cb231c759aaf54cbb
#   hostname: ip-172-16-30-231
#   info:
#     last_target_update_ts: 3500
#     learner:
#       default_policy:
#         custom_metrics: {}
#         learner_stats:
#           max_q: -359.59735107421875
#           mean_q: -76255.828125
#           min_q: -163579.9375
#           model: {}
#         num_agent_steps_trained: 256.0
#         td_error:
#         - 626.38671875
#         - 16894.515625
#         - 1788.0078125
#         - -392.6015625
#         - -630.5546875
#         - 484.5
#         - -658.796875
#         - 472.26171875
#         - 1986.44873046875
#         - -1067.15380859375
#         - -647.51171875
#         - -1503.3203125
#         - 17780.8984375
#         - 923.359375
#         - 10238.6484375
#         - 588.5390625
#         - 1798.87890625
#         - -49126.2578125
#         - 3605.16796875
#         - 8504.90625
#         - 2505.841796875
#         - 264.89453125
#         - 6100.8671875
#         - 186.890625
#         - 32432.59375
#         - 1692.359375
#         - 271.6171875
#         - -12.048095703125
#         - -1411.88671875
#         - 10740.7109375
#         - -982.005859375
#         - 3748.6298828125
#         - -225.080078125
#         - -59043.96875
#         - 1866.0849609375
#         - -37429.21484375
#         - 45.1015625
#         - 15044.5625
#         - 4189.796875
#         - 8612.0234375
#         - -28.4453125
#         - 20067.59375
#         - -211.0234375
#         - 779.0703125
#         - -596.7890625
#         - 10238.8046875
#         - -149.078125
#         - 119.8125
#         - -266.28125
#         - 372.115234375
#         - -793.14453125
#         - 1618.41015625
#         - 32.734375
#         - 472.26171875
#         - 2045.15625
#         - -1432.90625
#         - 7113.578125
#         - 2128.658203125
#         - -59043.96875
#         - 3566.717529296875
#         - 684.48828125
#         - -2296.00390625
#         - -1325.091796875
#         - 137.3359375
#         - 1105.095703125
#         - 1021.859375
#         - 1097.86328125
#         - 781.54296875
#         - 814.421875
#         - -335.90234375
#         - 14548.5625
#         - 36201.4375
#         - 820.8984375
#         - -664.71875
#         - 1831.1796875
#         - 164.640625
#         - -283.9296875
#         - 494.609375
#         - 2534.7890625
#         - -60372.78125
#         - -541.74609375
#         - -1149.5546875
#         - -61177.3046875
#         - 1742.615234375
#         - -2387.078125
#         - -1244.828125
#         - 531.87109375
#         - 449.9140625
#         - 19716.125
#         - -655.3671875
#         - 1297.5703125
#         - 3865.5390625
#         - 223.36328125
#         - -168.5234375
#         - 3566.717529296875
#         - -52758.015625
#         - -1759.8046875
#         - 977.046875
#         - -668.765625
#         - 4691.5
#         - 13878.234375
#         - 1311.40625
#         - -445.59375
#         - 1354.0078125
#     num_agent_steps_sampled: 3500
#     num_agent_steps_trained: 256256
#     num_steps_sampled: 3500
#     num_steps_trained: 256256
#     num_steps_trained_this_iter: 256
#     num_target_updates: 1001
#   iterations_since_restore: 3
#   node_ip: 172.16.30.231
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 3.58695652173913
#     ram_util_percent: 2.3999999999999995
#   pid: 71982
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.16196028241323338
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.31100298867652454
#     mean_inference_ms: 1.0449994776333436
#     mean_raw_obs_processing_ms: 0.4361883836226766
#   time_since_restore: 35.96109890937805
#   time_this_iter_s: 16.034424543380737
#   time_total_s: 35.96109890937805
#   timers:
#     learn_throughput: 46873.142
#     learn_time_ms: 5.462
#     load_throughput: 1146915.001
#     load_time_ms: 0.223
#     update_time_ms: 2.857
#   timestamp: 1650547198
#   timesteps_since_restore: 768
#   timesteps_this_iter: 256
#   timesteps_total: 3500
#   training_iteration: 3
#   trial_id: 9cd27_00000
#   warmup_time: 9.651880264282227
# == Status ==<br>Current time: 2022-04-21 13:20:03 (running for 00:00:59.00)<br>Memory usage on this node: 17.4/720.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3.0/64 CPUs, 0/16 GPUs, 0.0/516.84 GiB heap, 0.0/186.26 GiB objects (0.0/1.0 accelerator_type:K80)<br>Result logdir: /home/ec2-user/ray_results/DDPG<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                        </th><th>status  </th><th>loc                </th><th style="text-align: right;">   lr</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>DDPG_SimpleSupplyChain_9cd27_00000</td><td>RUNNING </td><td>172.16.30.231:71982</td><td style="text-align: right;">0.001</td><td style="text-align: right;">     3</td><td style="text-align: right;">         35.9611</td><td style="text-align: right;">3500</td><td style="text-align: right;"> -919874</td><td style="text-align: right;">             -472478</td><td style="text-align: right;">        -1.29692e+06</td><td style="text-align: right;">                25</td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-21 13:20:08 (running for 00:01:04.04)<br>Memory usage on this node: 17.4/720.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3.0/64 CPUs, 0/16 GPUs, 0.0/516.84 GiB heap, 0.0/186.26 GiB objects (0.0/1.0 accelerator_type:K80)<br>Result logdir: /home/ec2-user/ray_results/DDPG<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                        </th><th>status  </th><th>loc                </th><th style="text-align: right;">   lr</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>DDPG_SimpleSupplyChain_9cd27_00000</td><td>RUNNING </td><td>172.16.30.231:71982</td><td style="text-align: right;">0.001</td><td style="text-align: right;">     3</td><td style="text-align: right;">         35.9611</td><td style="text-align: right;">3500</td><td style="text-align: right;"> -919874</td><td style="text-align: right;">             -472478</td><td style="text-align: right;">        -1.29692e+06</td><td style="text-align: right;">                25</td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-21 13:20:13 (running for 00:01:09.04)<br>Memory usage on this node: 17.4/720.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3.0/64 CPUs, 0/16 GPUs, 0.0/516.84 GiB heap, 0.0/186.26 GiB objects (0.0/1.0 accelerator_type:K80)<br>Result logdir: /home/ec2-user/ray_results/DDPG<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                        </th><th>status  </th><th>loc                </th><th style="text-align: right;">   lr</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>DDPG_SimpleSupplyChain_9cd27_00000</td><td>RUNNING </td><td>172.16.30.231:71982</td><td style="text-align: right;">0.001</td><td style="text-align: right;">     3</td><td style="text-align: right;">         35.9611</td><td style="text-align: right;">3500</td><td style="text-align: right;"> -919874</td><td style="text-align: right;">             -472478</td><td style="text-align: right;">        -1.29692e+06</td><td style="text-align: right;">                25</td></tr>
# </tbody>
# </table><br><br>
# Result for DDPG_SimpleSupplyChain_9cd27_00000:
#   agent_timesteps_total: 4500
#   custom_metrics: {}
#   date: 2022-04-21_13-20-15
#   done: false
#   episode_len_mean: 25.0
#   episode_media: {}
#   episode_reward_max: -544949.6023029572
#   episode_reward_mean: -803480.4331916386
#   episode_reward_min: -1247079.2143253572
#   episodes_this_iter: 40
#   episodes_total: 180
#   experiment_id: 9f81eda9c1254e3cb231c759aaf54cbb
#   hostname: ip-172-16-30-231
#   info:
#     last_target_update_ts: 4500
#     learner:
#       default_policy:
#         custom_metrics: {}
#         learner_stats:
#           max_q: -1188.91162109375
#           mean_q: -107648.703125
#           min_q: -229103.578125
#           model: {}
#         num_agent_steps_trained: 256.0
#         td_error:
#         - -63456.1171875
#         - -639.7265625
#         - -1502.5390625
#         - -5556.2578125
#         - -3348.578125
#         - -7254.9765625
#         - -51731.828125
#         - -53929.9296875
#         - -7472.34375
#         - -2523.390625
#         - -2515.109375
#         - -2714.265625
#         - 193.234375
#         - 3951.359375
#         - -2840.8125
#         - -2317.0
#         - -55215.0859375
#         - 160.2109375
#         - 1329.796875
#         - 21852.6953125
#         - -1797.45703125
#         - -329.3984375
#         - 661.28125
#         - -73906.359375
#         - 32861.203125
#         - -1072.703125
#         - -1881.265625
#         - -2022.97265625
#         - -9662.65625
#         - -1091.6875
#         - -3498.328125
#         - -3649.640625
#         - -2527.234375
#         - -269.26953125
#         - 1040.75
#         - -3423.171875
#         - 5027.796875
#         - -39.6640625
#         - -3348.515625
#         - -1059.1328125
#         - 358.87890625
#         - -1638.421875
#         - -3212.8125
#         - -1378.390625
#         - -2608.3125
#         - 3281.34912109375
#         - -644.890625
#         - -913.2734375
#         - 5295.68896484375
#         - -1146.03125
#         - -697.96875
#         - -2007.244140625
#         - 1457.3828125
#         - 117.3125
#         - -7065.609375
#         - -1913.875
#         - -6864.078125
#         - -2034.515625
#         - 3047.4375
#         - 186.15625
#         - 1661.578125
#         - -396.84375
#         - -4339.96875
#         - -2493.4140625
#         - 732.546875
#         - 664.0078125
#         - 162.484375
#         - -619.625
#         - -39264.6328125
#         - 3209.546875
#         - -2490.796875
#         - -1605.5546875
#         - -1672.5078125
#         - 404.873046875
#         - 246.578125
#         - -10008.421875
#         - -1754.6875
#         - 53.125
#         - -2313.578125
#         - -1903.8203125
#         - -51973.421875
#         - -290.4921875
#         - -1022.84375
#         - 4463.7265625
#         - -2555.91796875
#         - -1376.671875
#         - -238.3125
#         - -2736.96875
#         - -2344.06640625
#         - 176.3828125
#         - -2114.46875
#         - -3863.1484375
#         - -1224.2890625
#         - 5248.7373046875
#         - -1852.2109375
#         - -10501.046875
#         - 4805.234375
#         - -1942.421875
#         - 107.609375
#         - 27698.96875
#         - 16274.9375
#         - -59111.63671875
#         - 897.80859375
#         - -1967.4296875
#         - -366.9765625
#     num_agent_steps_sampled: 4500
#     num_agent_steps_trained: 384256
#     num_steps_sampled: 4500
#     num_steps_trained: 384256
#     num_steps_trained_this_iter: 256
#     num_target_updates: 1501
#   iterations_since_restore: 4
#   node_ip: 172.16.30.231
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 3.8086956521739133
#     ram_util_percent: 2.3999999999999995
#   pid: 71982
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.1635488147562746
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.31501781771487886
# ...
#         - -26579.515625
#         - -11121.125
#         - 14.28125
#         - 3290.9375
#         - -7546.703125
#         - -1618.53125
#         - 2756.25
#         - -4922.78125
#         - -927.6875
#         - 3249.75
#         - -3046.5
#         - 1262.15625
#         - -1892.734375
#         - 42165.3125
#         - 4990.3125
#         - 6251.125
#         - 4702.25
#         - 905.5625
#         - -1412.28125
#         - 537.125
#         - 1770.3125
#         - 80.609375
#         - 797.9375
#     num_agent_steps_sampled: 48500
#     num_agent_steps_trained: 6016256
#     num_steps_sampled: 48500
#     num_steps_trained: 6016256
#     num_steps_trained_this_iter: 256
#     num_target_updates: 23501
#   iterations_since_restore: 48
#   node_ip: 172.16.30.231
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 3.6120000000000005
#     ram_util_percent: 2.5
#   pid: 71982
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.1756899240278509
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.3385446947022618
#     mean_inference_ms: 1.0353323486451158
#     mean_raw_obs_processing_ms: 0.4618124701644117
#   time_since_restore: 805.8847689628601
#   time_this_iter_s: 17.409077167510986
#   time_total_s: 805.8847689628601
#   timers:
#     learn_throughput: 45413.635
#     learn_time_ms: 5.637
#     load_throughput: 1179806.421
#     load_time_ms: 0.217
#     update_time_ms: 2.815
#   timestamp: 1650547971
#   timesteps_since_restore: 12288
#   timesteps_this_iter: 256
#   timesteps_total: 48500
#   training_iteration: 48
#   trial_id: 9cd27_00000
#   warmup_time: 9.651880264282227
# == Status ==<br>Current time: 2022-04-21 13:32:56 (running for 00:13:51.35)<br>Memory usage on this node: 17.9/720.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3.0/64 CPUs, 0/16 GPUs, 0.0/516.84 GiB heap, 0.0/186.26 GiB objects (0.0/1.0 accelerator_type:K80)<br>Result logdir: /home/ec2-user/ray_results/DDPG<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                        </th><th>status  </th><th>loc                </th><th style="text-align: right;">   lr</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">   ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>DDPG_SimpleSupplyChain_9cd27_00000</td><td>RUNNING </td><td>172.16.30.231:71982</td><td style="text-align: right;">0.001</td><td style="text-align: right;">    48</td><td style="text-align: right;">         805.885</td><td style="text-align: right;">48500</td><td style="text-align: right;"> -611787</td><td style="text-align: right;">             -604215</td><td style="text-align: right;">             -620209</td><td style="text-align: right;">                25</td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-21 13:33:01 (running for 00:13:56.35)<br>Memory usage on this node: 17.9/720.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3.0/64 CPUs, 0/16 GPUs, 0.0/516.84 GiB heap, 0.0/186.26 GiB objects (0.0/1.0 accelerator_type:K80)<br>Result logdir: /home/ec2-user/ray_results/DDPG<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                        </th><th>status  </th><th>loc                </th><th style="text-align: right;">   lr</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">   ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>DDPG_SimpleSupplyChain_9cd27_00000</td><td>RUNNING </td><td>172.16.30.231:71982</td><td style="text-align: right;">0.001</td><td style="text-align: right;">    48</td><td style="text-align: right;">         805.885</td><td style="text-align: right;">48500</td><td style="text-align: right;"> -611787</td><td style="text-align: right;">             -604215</td><td style="text-align: right;">             -620209</td><td style="text-align: right;">                25</td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-21 13:33:06 (running for 00:14:01.36)<br>Memory usage on this node: 17.9/720.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3.0/64 CPUs, 0/16 GPUs, 0.0/516.84 GiB heap, 0.0/186.26 GiB objects (0.0/1.0 accelerator_type:K80)<br>Result logdir: /home/ec2-user/ray_results/DDPG<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                        </th><th>status  </th><th>loc                </th><th style="text-align: right;">   lr</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">   ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>DDPG_SimpleSupplyChain_9cd27_00000</td><td>RUNNING </td><td>172.16.30.231:71982</td><td style="text-align: right;">0.001</td><td style="text-align: right;">    48</td><td style="text-align: right;">         805.885</td><td style="text-align: right;">48500</td><td style="text-align: right;"> -611787</td><td style="text-align: right;">             -604215</td><td style="text-align: right;">             -620209</td><td style="text-align: right;">                25</td></tr>
# </tbody>
# </table><br><br>
# Result for DDPG_SimpleSupplyChain_9cd27_00000:
#   agent_timesteps_total: 49500
#   custom_metrics: {}
#   date: 2022-04-21_13-33-08
#   done: false
#   episode_len_mean: 25.0
#   episode_media: {}
#   episode_reward_max: -604214.6249145751
#   episode_reward_mean: -611847.2304400878
#   episode_reward_min: -619599.257118631
#   episodes_this_iter: 40
#   episodes_total: 1980
#   experiment_id: 9f81eda9c1254e3cb231c759aaf54cbb
#   hostname: ip-172-16-30-231
#   info:
#     last_target_update_ts: 49500
#     learner:
#       default_policy:
#         custom_metrics: {}
#         learner_stats:
#           max_q: -48211.01171875
#           mean_q: -407751.53125
#           min_q: -556634.5625
#           model: {}
#         num_agent_steps_trained: 256.0
#         td_error:
#         - 5540.46875
#         - -366.03125
#         - 1717.375
#         - -5757.15625
#         - 4750.625
#         - -3788.6875
#         - -5207.0
#         - -866.5625
#         - 1637.5
#         - -1658.5625
#         - 2564.875
#         - -1011.40625
#         - 3350.65625
#         - -1263.125
#         - -8560.8125
#         - 3243.875
#         - -5273.3125
#         - -6254.96875
#         - -953.125
#         - 627.609375
#         - -3273.375
#         - 900.1875
#         - 5047.546875
#         - -1796.28125
#         - -6825.171875
#         - -10644.34375
#         - -9165.09375
#         - 30722.84375
#         - -4130.5234375
#         - 1108.1875
#         - 524.5625
#         - 5132.125
#         - -2361.375
#         - -2653.58203125
#         - -7011.15625
#         - 228.6875
#         - -5159.0
#         - 2615.625
#         - -2366.8125
#         - -1169.125
#         - 1640.5625
#         - -2281.2890625
#         - 2003.5625
#         - -6318.53125
#         - -18990.1875
#         - 2375.875
#         - 3123.65625
#         - -950.5
#         - -21563.6875
#         - -319.375
#         - -1112.390625
#         - 3351.65625
#         - 425.09375
#         - -617.03125
#         - -2230.375
#         - -387.25
#         - 5438.1875
#         - -2412.375
#         - 2231.125
#         - -6860.96875
#         - -3.21875
#         - 2064.5625
#         - 541.640625
#         - 985.875
#         - -1587.75
#         - 2327.0625
#         - 3927.09375
#         - -8070.0
#         - 1597.6875
#         - 1694.71875
#         - -3450.96875
#         - -3046.71875
#         - -2574.9375
#         - 4041.0625
#         - -3316.1875
#         - -603.5
#         - -3254.125
#         - -8854.125
#         - 2992.15625
#         - 5204.75
#         - -1582.65625
#         - -3840.78125
#         - 244.5859375
#         - -7898.0625
#         - -9369.25
#         - -4445.875
#         - -3082.9375
#         - -7334.75
#         - -1955.0625
#         - 1167.0625
#         - -6081.40625
#         - 2300.375
#         - 1581.25
#         - -610.0625
#         - -4188.34375
#         - -4876.125
#     num_agent_steps_sampled: 49500
#     num_agent_steps_trained: 6144256
#     num_steps_sampled: 49500
#     num_steps_trained: 6144256
#     num_steps_trained_this_iter: 256
#     num_target_updates: 24001
#   iterations_since_restore: 49
#   node_ip: 172.16.30.231
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 4.648
#     ram_util_percent: 2.5
#   pid: 71982
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.17588104605479254
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.33883958357832467
#     mean_inference_ms: 1.0358313694765682
#     mean_raw_obs_processing_ms: 0.46209731909488605
#   time_since_restore: 823.3801455497742
#   time_this_iter_s: 17.495376586914062
#   time_total_s: 823.3801455497742
#   timers:
#     learn_throughput: 44189.634
#     learn_time_ms: 5.793
#     load_throughput: 1175930.154
#     load_time_ms: 0.218
#     update_time_ms: 2.857
#   timestamp: 1650547988
#   timesteps_since_restore: 12544
#   timesteps_this_iter: 256
#   timesteps_total: 49500
#   training_iteration: 49
#   trial_id: 9cd27_00000
#   warmup_time: 9.651880264282227
# == Status ==<br>Current time: 2022-04-21 13:33:13 (running for 00:14:08.86)<br>Memory usage on this node: 17.9/720.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3.0/64 CPUs, 0/16 GPUs, 0.0/516.84 GiB heap, 0.0/186.26 GiB objects (0.0/1.0 accelerator_type:K80)<br>Result logdir: /home/ec2-user/ray_results/DDPG<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                        </th><th>status  </th><th>loc                </th><th style="text-align: right;">   lr</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">   ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>DDPG_SimpleSupplyChain_9cd27_00000</td><td>RUNNING </td><td>172.16.30.231:71982</td><td style="text-align: right;">0.001</td><td style="text-align: right;">    49</td><td style="text-align: right;">          823.38</td><td style="text-align: right;">49500</td><td style="text-align: right;"> -611847</td><td style="text-align: right;">             -604215</td><td style="text-align: right;">             -619599</td><td style="text-align: right;">                25</td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-21 13:33:18 (running for 00:14:13.90)<br>Memory usage on this node: 17.9/720.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3.0/64 CPUs, 0/16 GPUs, 0.0/516.84 GiB heap, 0.0/186.26 GiB objects (0.0/1.0 accelerator_type:K80)<br>Result logdir: /home/ec2-user/ray_results/DDPG<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                        </th><th>status  </th><th>loc                </th><th style="text-align: right;">   lr</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">   ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>DDPG_SimpleSupplyChain_9cd27_00000</td><td>RUNNING </td><td>172.16.30.231:71982</td><td style="text-align: right;">0.001</td><td style="text-align: right;">    49</td><td style="text-align: right;">          823.38</td><td style="text-align: right;">49500</td><td style="text-align: right;"> -611847</td><td style="text-align: right;">             -604215</td><td style="text-align: right;">             -619599</td><td style="text-align: right;">                25</td></tr>
# </tbody>
# </table><br><br>
# 2022-04-21 13:33:19,739	WARNING tune.py:651 -- SIGINT received (e.g. via Ctrl+C), ending Ray Tune run. This will try to checkpoint the experiment state one last time. Press CTRL+C one more time (or send SIGINT/SIGKILL/SIGTERM) to skip.
