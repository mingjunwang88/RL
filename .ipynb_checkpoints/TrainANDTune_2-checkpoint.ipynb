# %%
from ray.rllib.agents.ppo import PPOTrainer, DEFAULT_CONFIG
from ray.tune.logger import pretty_print
import json
import pandas as pd
import gym
import ray

ray.shutdown()
ray.init()

config = DEFAULT_CONFIG.copy()
config["num_workers"] = 1
config["num_sgd_iter"] = 30
config["sgd_minibatch_size"] = 128
config["model"]["fcnet_hiddens"] = [100, 100]
config["num_cpus_per_worker"] = 1

agent = PPOTrainer(config, "CartPole-v1")
# Out:
# WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/tensorflow_p36/gpu_cuda10.0/lib/python3.6/site-packages/tensorflow_core/__init__.py:1473: The name tf.estimator.inputs is deprecated. Please use tf.compat.v1.estimator.inputs instead.
# 2021-11-04 02:15:19,903	INFO services.py:1252 -- View the Ray dashboard at http://127.0.0.1:8266
# 2021-11-04 02:15:22,142	INFO trainer.py:741 -- Tip: set framework=tfe or the --eager flag to enable TensorFlow eager execution
# 2021-11-04 02:15:22,143	INFO ppo.py:165 -- In multi-agent mode, policies will be optimized sequentially by the multi-GPU optimizer. Consider setting simple_optimizer=True if this doesn't work for you.
# 2021-11-04 02:15:22,144	INFO trainer.py:760 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# (pid=5367) WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/tensorflow_p36/gpu_cuda10.0/lib/python3.6/site-packages/tensorflow_core/__init__.py:1473: The name tf.estimator.inputs is deprecated. Please use tf.compat.v1.estimator.inputs instead.
# (pid=5367)
# (pid=5367) 2021-11-04 02:15:30.985507: E tensorflow/stream_executor/cuda/cuda_driver.cc:318] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# (pid=5367) WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/tensorflow_p36/gpu_cuda10.0/lib/python3.6/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# (pid=5367) Instructions for updating:
# (pid=5367) If using Keras pass *_constraint arguments to layers.
# (pid=5367) WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/tensorflow_p36/gpu_cuda10.0/lib/python3.6/site-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# (pid=5367) Instructions for updating:
# (pid=5367) Use tf.where in 2.0, which has the same broadcast rule as np.where
# (pid=5367) WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/horovod/tensorflow/__init__.py:163: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
# (pid=5367)
# (pid=5367) WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/horovod/tensorflow/__init__.py:189: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
# (pid=5367)
# (RolloutWorker pid=5367) [2021-11-04 02:15:34.033 ip-172-16-83-177:5367 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# (RolloutWorker pid=5367) [2021-11-04 02:15:34.164 ip-172-16-83-177:5367 INFO profiler_config_parser.py:111] Unable to find config at /opt/ml/input/config/profilerconfig.json. Profiler is disabled.
# WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/tensorflow_p36/gpu_cuda10.0/lib/python3.6/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/tensorflow_p36/gpu_cuda10.0/lib/python3.6/site-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/horovod/tensorflow/__init__.py:163: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/horovod/tensorflow/__init__.py:189: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# [2021-11-04 02:16:09.337 ip-172-16-83-177:130210 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2021-11-04 02:16:09.370 ip-172-16-83-177:130210 INFO profiler_config_parser.py:111] Unable to find config at /opt/ml/input/config/profilerconfig.json. Profiler is disabled.
# 2021-11-04 02:16:09,912	WARNING trainer_template.py:186 -- `execution_plan` functions should accept `trainer`, `workers`, and `config` as args!
# 2021-11-04 02:16:09,913	INFO trainable.py:112 -- Trainable.setup took 47.772 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.

# %%
import tensorflow

# %%
# Import the RL algorithm (Trainer) we would like to use.
from ray.rllib.agents.ppo import PPOTrainer

# Configure the algorithm.
config = {
    # Environment (RLlib understands openAI gym registered strings).
    "env": "Taxi-v3",
    # Use 2 environment workers (aka "rollout workers") that parallelly
    # collect samples from their own environment clone(s).
    "num_workers": 2,
    # Change this to "framework: torch", if you are using PyTorch.
    # Also, use "framework: tf2" for tf2.x eager execution.
    "framework": "tf",
    # Tweak the default model provided automatically by RLlib,
    # given the environment's observation- and action spaces.
    "model": {
        "fcnet_hiddens": [64, 64],
        "fcnet_activation": "relu",
    },
    # Set up a separate evaluation worker set for the
    # `trainer.evaluate()` call after training (see below).
    "evaluation_num_workers": 1,
    # Only for evaluation runs, render the env.
    "evaluation_config": {
        "render_env": True,
    }
}

# Create our RLlib Trainer.
trainer = PPOTrainer(config=config)

# Run it for n training iterations. A training iteration includes
# parallel sample collection by the environment workers as well as
# loss calculation on the collected batch and a model update.
for _ in range(3):
    print(trainer.train())

# Evaluate the trained Trainer (and render each timestep to the shell's
# output).
trainer.evaluate()
# Out:
# WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/tensorflow_p36/gpu_cuda10.0/lib/python3.6/site-packages/tensorflow_core/__init__.py:1473: The name tf.estimator.inputs is deprecated. Please use tf.compat.v1.estimator.inputs instead.
# 2022-03-20 17:16:14,141	WARNING trainer.py:2348 -- You have specified 1 evaluation workers, but your `evaluation_interval` is None! Therefore, evaluation will not occur automatically with each call to `Trainer.train()`. Instead, you will have to call `Trainer.evaluate()` manually in order to trigger an evaluation run.
# 2022-03-20 17:16:16,735	INFO services.py:1414 -- View the Ray dashboard at http://127.0.0.1:8266
# (pid=110886) WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/tensorflow_p36/gpu_cuda10.0/lib/python3.6/site-packages/tensorflow_core/__init__.py:1473: The name tf.estimator.inputs is deprecated. Please use tf.compat.v1.estimator.inputs instead.
# (pid=110886)
# (pid=110882) WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/tensorflow_p36/gpu_cuda10.0/lib/python3.6/site-packages/tensorflow_core/__init__.py:1473: The name tf.estimator.inputs is deprecated. Please use tf.compat.v1.estimator.inputs instead.
# (pid=110882)
# (RolloutWorker pid=110886) 2022-03-20 17:16:22.776580: E tensorflow/stream_executor/cuda/cuda_driver.cc:318] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# (RolloutWorker pid=110886) WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/tensorflow_p36/gpu_cuda10.0/lib/python3.6/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# (RolloutWorker pid=110886) Instructions for updating:
# (RolloutWorker pid=110886) If using Keras pass *_constraint arguments to layers.
# (RolloutWorker pid=110882) 2022-03-20 17:16:22.829152: E tensorflow/stream_executor/cuda/cuda_driver.cc:318] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# (RolloutWorker pid=110882) WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/tensorflow_p36/gpu_cuda10.0/lib/python3.6/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# (RolloutWorker pid=110882) Instructions for updating:
# (RolloutWorker pid=110882) If using Keras pass *_constraint arguments to layers.
# (RolloutWorker pid=110886) WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/tensorflow_p36/gpu_cuda10.0/lib/python3.6/site-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# (RolloutWorker pid=110886) Instructions for updating:
# (RolloutWorker pid=110886) Use tf.where in 2.0, which has the same broadcast rule as np.where
# (RolloutWorker pid=110882) WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/tensorflow_p36/gpu_cuda10.0/lib/python3.6/site-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# (RolloutWorker pid=110882) Instructions for updating:
# (RolloutWorker pid=110882) Use tf.where in 2.0, which has the same broadcast rule as np.where
# (RolloutWorker pid=110886) WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/horovod/tensorflow/__init__.py:163: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
# (RolloutWorker pid=110886)
# (RolloutWorker pid=110886) WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/horovod/tensorflow/__init__.py:189: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
# (RolloutWorker pid=110886)
# (RolloutWorker pid=110882) WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/horovod/tensorflow/__init__.py:163: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
# (RolloutWorker pid=110882)
# (RolloutWorker pid=110882) WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/horovod/tensorflow/__init__.py:189: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
# (RolloutWorker pid=110882)
# (RolloutWorker pid=110882) [2022-03-20 17:16:23.641 ip-172-16-6-103:110882 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# (RolloutWorker pid=110886) [2022-03-20 17:16:23.635 ip-172-16-6-103:110886 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# (RolloutWorker pid=110882) [2022-03-20 17:16:23.673 ip-172-16-6-103:110882 INFO profiler_config_parser.py:111] Unable to find config at /opt/ml/input/config/profilerconfig.json. Profiler is disabled.
# (RolloutWorker pid=110886) [2022-03-20 17:16:23.667 ip-172-16-6-103:110886 INFO profiler_config_parser.py:111] Unable to find config at /opt/ml/input/config/profilerconfig.json. Profiler is disabled.
# WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/tensorflow_p36/gpu_cuda10.0/lib/python3.6/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/tensorflow_p36/gpu_cuda10.0/lib/python3.6/site-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/horovod/tensorflow/__init__.py:163: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/horovod/tensorflow/__init__.py:189: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# [2022-03-20 17:17:02.776 ip-172-16-6-103:110333 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2022-03-20 17:17:02.808 ip-172-16-6-103:110333 INFO profiler_config_parser.py:111] Unable to find config at /opt/ml/input/config/profilerconfig.json. Profiler is disabled.
# 2022-03-20 17:17:03,341	WARNING deprecation.py:46 -- DeprecationWarning: `simple_optimizer` has been deprecated. This will raise an error in the future!
# 2022-03-20 17:17:03,342	WARNING trainer.py:2348 -- You have specified 1 evaluation workers, but your `evaluation_interval` is None! Therefore, evaluation will not occur automatically with each call to `Trainer.train()`. Instead, you will have to call `Trainer.evaluate()` manually in order to trigger an evaluation run.
# 2022-03-20 17:17:03,418	INFO trainable.py:130 -- Trainable.setup took 49.278 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2022-03-20 17:17:03,419	WARNING util.py:55 -- Install gputil for GPU system monitoring.
# (pid=110863) WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/tensorflow_p36/gpu_cuda10.0/lib/python3.6/site-packages/tensorflow_core/__init__.py:1473: The name tf.estimator.inputs is deprecated. Please use tf.compat.v1.estimator.inputs instead.
# (pid=110863)
# 2022-03-20 17:17:05,882	WARNING deprecation.py:46 -- DeprecationWarning: `slice` has been deprecated. Use `SampleBatch[start:stop]` instead. This will raise an error in the future!
# (RolloutWorker pid=110863) 2022-03-20 17:17:06.653893: E tensorflow/stream_executor/cuda/cuda_driver.cc:318] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# (RolloutWorker pid=110863) WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/tensorflow_p36/gpu_cuda10.0/lib/python3.6/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# (RolloutWorker pid=110863) Instructions for updating:
# (RolloutWorker pid=110863) If using Keras pass *_constraint arguments to layers.
# (RolloutWorker pid=110863) WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/tensorflow_p36/gpu_cuda10.0/lib/python3.6/site-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# (RolloutWorker pid=110863) Instructions for updating:
# (RolloutWorker pid=110863) Use tf.where in 2.0, which has the same broadcast rule as np.where
# (RolloutWorker pid=110863) WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/horovod/tensorflow/__init__.py:163: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
# (RolloutWorker pid=110863)
# (RolloutWorker pid=110863) WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/horovod/tensorflow/__init__.py:189: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
# (RolloutWorker pid=110863)
# (RolloutWorker pid=110863) [2022-03-20 17:17:07.531 ip-172-16-6-103:110863 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# (RolloutWorker pid=110863) [2022-03-20 17:17:07.565 ip-172-16-6-103:110863 INFO profiler_config_parser.py:111] Unable to find config at /opt/ml/input/config/profilerconfig.json. Profiler is disabled.
# {'episode_reward_max': -227.0, 'episode_reward_min': -902.0, 'episode_reward_mean': -739.1, 'episode_len_mean': 194.3, 'episode_media': {}, 'episodes_this_iter': 20, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [-623.0, -776.0, -776.0, -695.0, -740.0, -794.0, -731.0, -884.0, -731.0, -722.0, -722.0, -731.0, -830.0, -713.0, -902.0, -803.0, -227.0, -731.0, -866.0, -785.0], 'episode_lengths': [200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 86, 200, 200, 200]}, 'sampler_perf': {'mean_raw_obs_processing_ms': 0.11727215348929539, 'mean_inference_ms': 0.8937789463270074, 'mean_action_processing_ms': 0.08494808696497087, 'mean_env_wait_ms': 0.0862189973967484, 'mean_env_render_ms': 0.0}, 'off_policy_estimator': {}, 'num_healthy_workers': 2, 'timesteps_total': 4000, 'timesteps_this_iter': 4000, 'agent_timesteps_total': 4000, 'timers': {'sample_time_ms': 2540.727, 'sample_throughput': 1574.353, 'load_time_ms': 0.502, 'load_throughput': 7962608.448, 'learn_time_ms': 4920.705, 'learn_throughput': 812.892, 'update_time_ms': 2.371}, 'info': {'learner': {'default_policy': {'learner_stats': {'cur_kl_coeff': 0.20000000298023224, 'cur_lr': 4.999999873689376e-05, 'total_loss': 51208.438, 'policy_loss': 0.008909906, 'vf_loss': 51208.43, 'vf_explained_var': 2.7403588e-05, 'kl': 0.0007080862, 'entropy': 1.7910558, 'entropy_coeff': 0.0, 'model': {}}, 'custom_metrics': {}}}, 'num_steps_sampled': 4000, 'num_agent_steps_sampled': 4000, 'num_steps_trained': 4000, 'num_steps_trained_this_iter': 4000, 'num_agent_steps_trained': 4000}, 'done': False, 'episodes_total': 20, 'training_iteration': 1, 'trial_id': 'default', 'experiment_id': '48239607ccd8409d90ac937098708936', 'date': '2022-03-20_17-17-10', 'timestamp': 1647796630, 'time_this_iter_s': 7.413206577301025, 'time_total_s': 7.413206577301025, 'pid': 110333, 'hostname': 'ip-172-16-6-103', 'node_ip': '172.16.6.103', 'config': {'num_workers': 2, 'num_envs_per_worker': 1, 'create_env_on_driver': False, 'rollout_fragment_length': 200, 'batch_mode': 'truncate_episodes', 'gamma': 0.99, 'lr': 5e-05, 'train_batch_size': 4000, 'model': {'_use_default_native_models': False, '_disable_preprocessor_api': False, '_disable_action_flattening': False, 'fcnet_hiddens': [64, 64], 'fcnet_activation': 'relu', 'conv_filters': None, 'conv_activation': 'relu', 'post_fcnet_hiddens': [], 'post_fcnet_activation': 'relu', 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': False, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action': False, 'lstm_use_prev_reward': False, '_time_major': False, 'use_attention': False, 'attention_num_transformer_units': 1, 'attention_dim': 64, 'attention_num_heads': 1, 'attention_head_dim': 32, 'attention_memory_inference': 50, 'attention_memory_training': 50, 'attention_position_wise_mlp_dim': 32, 'attention_init_gru_gate_bias': 2.0, 'attention_use_n_prev_actions': 0, 'attention_use_n_prev_rewards': 0, 'framestack': True, 'dim': 84, 'grayscale': False, 'zero_mean': True, 'custom_model': None, 'custom_model_config': {}, 'custom_action_dist': None, 'custom_preprocessor': None, 'lstm_use_prev_action_reward': -1}, 'optimizer': {}, 'horizon': None, 'soft_horizon': False, 'no_done_at_end': False, 'env': 'Taxi-v3', 'observation_space': None, 'action_space': None, 'env_config': {}, 'remote_worker_envs': False, 'remote_env_batch_wait_ms': 0, 'env_task_fn': None, 'render_env': False, 'record_env': False, 'clip_rewards': None, 'normalize_actions': True, 'clip_actions': False, 'preprocessor_pref': 'deepmind', 'log_level': 'WARN', 'callbacks': <class 'ray.rllib.agents.callbacks.DefaultCallbacks'>, 'ignore_worker_failures': False, 'log_sys_usage': True, 'fake_sampler': False, 'framework': 'tf', 'eager_tracing': False, 'eager_max_retraces': 20, 'explore': True, 'exploration_config': {'type': 'StochasticSampling'}, 'evaluation_interval': None, 'evalua ...
# {'episode_reward_max': -227.0, 'episode_reward_min': -902.0, 'episode_reward_mean': -719.975, 'episode_len_mean': 197.15, 'episode_media': {}, 'episodes_this_iter': 20, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [-623.0, -776.0, -776.0, -695.0, -740.0, -794.0, -731.0, -884.0, -731.0, -722.0, -722.0, -731.0, -830.0, -713.0, -902.0, -803.0, -227.0, -731.0, -866.0, -785.0, -758.0, -740.0, -713.0, -686.0, -677.0, -632.0, -650.0, -668.0, -686.0, -722.0, -866.0, -677.0, -677.0, -713.0, -686.0, -677.0, -659.0, -758.0, -749.0, -623.0], 'episode_lengths': [200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 86, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200]}, 'sampler_perf': {'mean_raw_obs_processing_ms': 0.11731398176942909, 'mean_inference_ms': 0.8737339320164418, 'mean_action_processing_ms': 0.08461926472360001, 'mean_env_wait_ms': 0.08623656530894934, 'mean_env_render_ms': 0.0}, 'off_policy_estimator': {}, 'num_healthy_workers': 2, 'timesteps_total': 8000, 'timesteps_this_iter': 4000, 'agent_timesteps_total': 8000, 'timers': {'sample_time_ms': 4901.063, 'sample_throughput': 816.15, 'load_time_ms': 0.503, 'load_throughput': 7955057.373, 'learn_time_ms': 4765.536, 'learn_throughput': 839.36, 'update_time_ms': 2.383}, 'info': {'learner': {'default_policy': {'learner_stats': {'cur_kl_coeff': 0.10000000149011612, 'cur_lr': 4.999999873689376e-05, 'total_loss': 32608.143, 'policy_loss': -0.00010814141, 'vf_loss': 32608.14, 'vf_explained_var': 0.00034158365, 'kl': 0.009088553, 'entropy': 1.770181, 'entropy_coeff': 0.0, 'model': {}}, 'custom_metrics': {}}}, 'num_steps_sampled': 8000, 'num_agent_steps_sampled': 8000, 'num_steps_trained': 8000, 'num_steps_trained_this_iter': 4000, 'num_agent_steps_trained': 8000}, 'done': False, 'episodes_total': 40, 'training_iteration': 2, 'trial_id': 'default', 'experiment_id': '48239607ccd8409d90ac937098708936', 'date': '2022-03-20_17-17-17', 'timestamp': 1647796637, 'time_this_iter_s': 6.910207986831665, 'time_total_s': 14.32341456413269, 'pid': 110333, 'hostname': 'ip-172-16-6-103', 'node_ip': '172.16.6.103', 'config': {'num_workers': 2, 'num_envs_per_worker': 1, 'create_env_on_driver': False, 'rollout_fragment_length': 200, 'batch_mode': 'truncate_episodes', 'gamma': 0.99, 'lr': 5e-05, 'train_batch_size': 4000, 'model': {'_use_default_native_models': False, '_disable_preprocessor_api': False, '_disable_action_flattening': False, 'fcnet_hiddens': [64, 64], 'fcnet_activation': 'relu', 'conv_filters': None, 'conv_activation': 'relu', 'post_fcnet_hiddens': [], 'post_fcnet_activation': 'relu', 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': False, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action': False, 'lstm_use_prev_reward': False, '_time_major': False, 'use_attention': False, 'attention_num_transformer_units': 1, 'attention_dim': 64, 'attention_num_heads': 1, 'attention_head_dim': 32, 'attention_memory_inference': 50, 'attention_memory_training': 50, 'attention_position_wise_mlp_dim': 32, 'attention_init_gru_gate_bias': 2.0, 'attention_use_n_prev_actions': 0, 'attention_use_n_prev_rewards': 0, 'framestack': True, 'dim': 84, 'grayscale': False, 'zero_mean': True, 'custom_model': None, 'custom_model_config': {}, 'custom_action_dist': None, 'custom_preprocessor': None, 'lstm_use_prev_action_reward': -1}, 'optimizer': {}, 'horizon': None, 'soft_horizon': False, 'no_done_at_end': False, 'env': 'Taxi-v3', 'observation_space': None, 'action_space': None, 'env_config': {}, 'remote_worker_envs': False, 'remote_env_batch_wait_ms': 0, 'env_task_fn': None, 'render_env': False, 'record_env': False, 'clip_rewards': None, 'normalize_actions': True, 'clip_actions': False, 'preprocessor_pref': 'deepmind', 'log_level': 'WARN', 'callbacks': <class 'ray.rllib.agents.callbacks.DefaultCallba ...
# {'episode_reward_max': -227.0, 'episode_reward_min': -902.0, 'episode_reward_mean': -672.5666666666667, 'episode_len_mean': 196.41666666666666, 'episode_media': {}, 'episodes_this_iter': 20, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [-623.0, -776.0, -776.0, -695.0, -740.0, -794.0, -731.0, -884.0, -731.0, -722.0, -722.0, -731.0, -830.0, -713.0, -902.0, -803.0, -227.0, -731.0, -866.0, -785.0, -758.0, -740.0, -713.0, -686.0, -677.0, -632.0, -650.0, -668.0, -686.0, -722.0, -866.0, -677.0, -677.0, -713.0, -686.0, -677.0, -659.0, -758.0, -749.0, -623.0, -704.0, -542.0, -596.0, -506.0, -596.0, -659.0, -596.0, -240.0, -533.0, -686.0, -713.0, -587.0, -587.0, -641.0, -605.0, -560.0, -605.0, -587.0, -506.0, -506.0], 'episode_lengths': [200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 86, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 99, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200]}, 'sampler_perf': {'mean_raw_obs_processing_ms': 0.11745504816860945, 'mean_inference_ms': 0.8630224703094899, 'mean_action_processing_ms': 0.08440351939030609, 'mean_env_wait_ms': 0.08622545516869952, 'mean_env_render_ms': 0.0}, 'off_policy_estimator': {}, 'num_healthy_workers': 2, 'timesteps_total': 12000, 'timesteps_this_iter': 4000, 'agent_timesteps_total': 12000, 'timers': {'sample_time_ms': 5574.301, 'sample_throughput': 717.579, 'load_time_ms': 0.497, 'load_throughput': 8053063.68, 'learn_time_ms': 4717.89, 'learn_throughput': 847.837, 'update_time_ms': 2.484}, 'info': {'learner': {'default_policy': {'learner_stats': {'cur_kl_coeff': 0.10000000149011612, 'cur_lr': 4.999999873689376e-05, 'total_loss': 18005.467, 'policy_loss': -0.0034328816, 'vf_loss': 18005.467, 'vf_explained_var': 0.00067220966, 'kl': 0.008934321, 'entropy': 1.7275414, 'entropy_coeff': 0.0, 'model': {}}, 'custom_metrics': {}}}, 'num_steps_sampled': 12000, 'num_agent_steps_sampled': 12000, 'num_steps_trained': 12000, 'num_steps_trained_this_iter': 4000, 'num_agent_steps_trained': 12000}, 'done': False, 'episodes_total': 60, 'training_iteration': 3, 'trial_id': 'default', 'experiment_id': '48239607ccd8409d90ac937098708936', 'date': '2022-03-20_17-17-24', 'timestamp': 1647796644, 'time_this_iter_s': 6.917158365249634, 'time_total_s': 21.240572929382324, 'pid': 110333, 'hostname': 'ip-172-16-6-103', 'node_ip': '172.16.6.103', 'config': {'num_workers': 2, 'num_envs_per_worker': 1, 'create_env_on_driver': False, 'rollout_fragment_length': 200, 'batch_mode': 'truncate_episodes', 'gamma': 0.99, 'lr': 5e-05, 'train_batch_size': 4000, 'model': {'_use_default_native_models': False, '_disable_preprocessor_api': False, '_disable_action_flattening': False, 'fcnet_hiddens': [64, 64], 'fcnet_activation': 'relu', 'conv_filters': None, 'conv_activation': 'relu', 'post_fcnet_hiddens': [], 'post_fcnet_activation': 'relu', 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': False, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action': False, 'lstm_use_prev_reward': False, '_time_major': False, 'use_attention': False, 'attention_num_transformer_units': 1, 'attention_dim': 64, 'attention_num_heads': 1, 'attention_head_dim': 32, 'attention_memory_inference': 50, 'attention_memory_training': 50, 'attention_position_wise_mlp_dim': 32, 'attention_init_gru_gate_bias': 2.0, 'attention_use_n_prev_actions': 0, 'attention_use_n_prev_rewards': 0, 'framestack': True, 'dim': 84, 'grayscale': False, 'zero_mean': True, 'custom_model': None, 'custom_model_config': {}, 'custom_action_dist': None, 'custom_preprocessor': None, 'lstm_use_prev_action_reward': -1}, 'optimizer': {}, 'horizon': None, 'soft_horizon': False, 'no_done_at_end': False, 'env': 'Taxi-v3', 'observation_space': None, 'action_space': None, 'env_config': {}, 'remote_worker_envs': ...
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (Dropoff)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (East)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (South)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (West)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (East)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (East)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (South)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (West)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (Pickup)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (East)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (North)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (South)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (North)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (West)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (South)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (South)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (West)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (East)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (South)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (West)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (West)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (West)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (South)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (North)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (Pickup)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (North)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (West)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (North)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (North)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (West)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (East)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (East)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (North)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (East)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (West)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (West)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (East)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (Dropoff)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (South)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (Pickup)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (East)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (East)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (North)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (South)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (Pickup)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (North)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (West)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (South)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (West)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (Dropoff)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (East)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (North)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (South)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (West)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (West)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (Pickup)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (West)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (Dropoff)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (South)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (West)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (West)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (East)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (South)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (West)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (West)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (East)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (West)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (North)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (West)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (North)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (East)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (North)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (West)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (East)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (East)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (North)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (East)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (West)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (West)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (West)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (West)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (North)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (East)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (East)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# ...
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (South)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (North)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (East)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (Dropoff)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (North)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (East)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (East)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (West)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (East)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (North)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (West)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (Dropoff)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (South)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (Dropoff)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (East)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (West)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (Dropoff)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (South)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (East)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (West)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (North)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (North)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (North)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (North)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (West)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (West)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (Dropoff)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (East)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (Dropoff)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (Pickup)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (North)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (North)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (East)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (East)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (South)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (North)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (West)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (South)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (East)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (South)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (South)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (East)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (West)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (Dropoff)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (East)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (North)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (North)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (Pickup)
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863) |R: | : :G|
# (RolloutWorker pid=110863) | : | : : |
# (RolloutWorker pid=110863) | : : : : |
# (RolloutWorker pid=110863) | | : | : |
# (RolloutWorker pid=110863) |Y| : |B: |
# (RolloutWorker pid=110863) +---------+
# (RolloutWorker pid=110863)   (Pickup)
# {'evaluation': {'episode_reward_max': -434.0,
#   'episode_reward_min': -578.0,
#   'episode_reward_mean': -509.6,
#   'episode_len_mean': 200.0,
#   'episode_media': {},
#   'episodes_this_iter': 10,
#   'policy_reward_min': {},
#   'policy_reward_max': {},
#   'policy_reward_mean': {},
#   'custom_metrics': {},
#   'hist_stats': {'episode_reward': [-443.0,
#     -434.0,
#     -578.0,
#     -506.0,
#     -560.0,
#     -434.0,
#     -506.0,
#     -551.0,
#     -515.0,
#     -569.0],
#    'episode_lengths': [200, 200, 200, 200, 200, 200, 200, 200, 200, 200]},
#   'sampler_perf': {'mean_raw_obs_processing_ms': 0.11502105792959232,
#    'mean_inference_ms': 0.8344184393170236,
#    'mean_action_processing_ms': 0.08353955861272244,
#    'mean_env_wait_ms': 0.08635244507720505,
#    'mean_env_render_ms': 0.06819569665393134},
#   'off_policy_estimator': {},
#   'timesteps_this_iter': 0}}

# %%
import ray
import ray.rllib.agents.ppo as ppo
from ray.tune.logger import pretty_print
from ray import tune
