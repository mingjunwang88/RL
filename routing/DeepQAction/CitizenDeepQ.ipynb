# %%
from agents import Model, replayBuffer, Agent
from env import CitizenBankEnv
from torch_geometric.utils import to_networkx, from_networkx

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('links.csv')[['DeviceA_Code','DeviceB_Code']]
points_list = [(i,j) for i,j in df.values]

import networkx as nx
G=nx.Graph()
G.add_edges_from(points_list)
pos = nx.spring_layout(G, seed=0)

seperate = True
if seperate:
    nx.draw_networkx_nodes(G,pos)
    nx.draw_networkx_edges(G,pos)
    nx.draw_networkx_labels(G,pos)
    plt.show()
else:
    #nx.draw_networkx(G, pos=nx.spring_layout(G, seed=0), with_labels=True, node_color=data.y, cmap="Set2")
    nx.draw_networks(G)
    plt.show()

# %%
# !pip install torch_geometric
# Out:
# Collecting torch_geometric
#   Downloading torch_geometric-2.3.1.tar.gz (661 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 661.6/661.6 kB 7.5 MB/s eta 0:00:0000:0100:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: tqdm in /Users/wangmi/opt/miniconda3/envs/ray/lib/python3.9/site-packages (from torch_geometric) (4.64.1)
# Requirement already satisfied: jinja2 in /Users/wangmi/opt/miniconda3/envs/ray/lib/python3.9/site-packages (from torch_geometric) (3.1.2)
# Requirement already satisfied: scikit-learn in /Users/wangmi/opt/miniconda3/envs/ray/lib/python3.9/site-packages (from torch_geometric) (1.2.2)
# Requirement already satisfied: psutil>=5.8.0 in /Users/wangmi/opt/miniconda3/envs/ray/lib/python3.9/site-packages (from torch_geometric) (5.9.3)
# Requirement already satisfied: numpy in /Users/wangmi/opt/miniconda3/envs/ray/lib/python3.9/site-packages (from torch_geometric) (1.23.4)
# Requirement already satisfied: pyparsing in /Users/wangmi/opt/miniconda3/envs/ray/lib/python3.9/site-packages (from torch_geometric) (3.0.9)
# Requirement already satisfied: scipy in /Users/wangmi/opt/miniconda3/envs/ray/lib/python3.9/site-packages (from torch_geometric) (1.9.3)
# Requirement already satisfied: requests in /Users/wangmi/opt/miniconda3/envs/ray/lib/python3.9/site-packages (from torch_geometric) (2.28.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/wangmi/opt/miniconda3/envs/ray/lib/python3.9/site-packages (from jinja2->torch_geometric) (2.1.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/wangmi/opt/miniconda3/envs/ray/lib/python3.9/site-packages (from requests->torch_geometric) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/wangmi/opt/miniconda3/envs/ray/lib/python3.9/site-packages (from requests->torch_geometric) (1.26.12)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/wangmi/opt/miniconda3/envs/ray/lib/python3.9/site-packages (from requests->torch_geometric) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /Users/wangmi/opt/miniconda3/envs/ray/lib/python3.9/site-packages (from requests->torch_geometric) (3.4)
# Requirement already satisfied: joblib>=1.1.1 in /Users/wangmi/opt/miniconda3/envs/ray/lib/python3.9/site-packages (from scikit-learn->torch_geometric) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/wangmi/opt/miniconda3/envs/ray/lib/python3.9/site-packages (from scikit-learn->torch_geometric) (3.1.0)
# Building wheels for collected packages: torch_geometric
#   Building wheel for torch_geometric (pyproject.toml) ... done
#   Created wheel for torch_geometric: filename=torch_geometric-2.3.1-py3-none-any.whl size=910459 sha256=e57fd35f990e889e0c19d81a9968a6a886c3e966d63a215f1d9ab569d27378be
#   Stored in directory: /Users/wangmi/Library/Caches/pip/wheels/75/cc/0c/029f33b5cb29c590a061faf5202ea24956388bba7f1af50f2e
# Successfully built torch_geometric
# Installing collected packages: torch_geometric
# Successfully installed torch_geometric-2.3.1

# %% [markdown]
# ## Q Learning Embedding

# %%
import date_time
import importlib
import agents
importlib.reload(agents)
from agents import *
import env
importlib.reload(env)
from env import *

env = CitizenBankEnv()
src = env.state
dest = env.dest
               #env, num_state,       dim_state,dim_action,h1, h2, max_memsize, alpha=1e-4, batch_size=258, max_iters = 30, epsilon=0.05, steps_target=1000, gamma=0.99):
trainer = Agent(env, env.num_devices, 20,       20,        30, 20, 10000,       alpha=2.5e-5, batch_size=236,  max_iters =20, epsilon=0.05, steps_target=500, gamma=0.95)
trainer.train()
"""
if reward_list:
    x = [i+1 for i in range(iters)]
    trainer.plot_learning_curve(x, reward_list)
    path, cost = trainer.find_path(src, dest)
    print('qlearning path: ', path, 'cost: ', cost)
print('dijkstra path:  ', nx.shortest_path(G, src, dest, weight='Bandwidth (Mbps)'))
"""

#path, cost = trainer.find_path(0)

#print(path)
#print('cost: ', cost)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [4], line 1
# ----> 1 import date_time
#       2 import importlib
#       3 import agents
#
# ModuleNotFoundError: No module named 'date_time'

# %%
path, cost = trainer.find_path(25, 20)

print(path)
print('cost: ', cost)

# %% [markdown]
# ## Q learning One Hot
#
# ### Only dest

# %%
import importlib
import dest.agent_one_hot_d
importlib.reload(dest.agent_one_hot_d)
from dest.agent_one_hot_d import *
import dest.env_one_hot_d
importlib.reload(dest.env_one_hot_d)
from dest.env_one_hot_d import *

import time 
start_time = time.time()


dest = 12

for dest in range(3):
    env = CitizenBankEnv(dest)
    trainer = Agent(env, env.num_devices, 50, 50, 1000, alpha=2.5e-5, batch_size=126,  max_iters =40 , epsilon=1, min_epsilon=0.03, steps_target=100, gamma=0.95)
    trainer.train()
    
    for src in range(trainer.env.num_devices):
        if src != dest:
            path, cost = trainer.find_path(src)

            print('cost:        ', cost)
            print('DQ learning path: ', path)
            print('dijkstra path:    ', nx.shortest_path(G, src, dest, weight='Bandwidth (Mbps)'))
    
print('---- {} seconds'.format(time.time() - start_time))
"""
if reward_list:
    x = [i+1 for i in range(iters)]
    trainer.plot_learning_curve(x, reward_list)
    path, cost = trainer.find_path(src, dest)
    print('qlearning path: ', path, 'cost: ', cost)
print('dijkstra path:  ', nx.shortest_path(G, src, dest, weight='Bandwidth (Mbps)'))
"""
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 40/40 [00:32<00:00,  1.22it/s]
# cost:         2000.0
# DQ learning path:  [1, 3, 0]
# dijkstra path:     [1, 2, 0]
# cost:         1000.0
# DQ learning path:  [2, 0]
# dijkstra path:     [2, 0]
# cost:         1000.0
# DQ learning path:  [3, 0]
# dijkstra path:     [3, 0]
# cost:         2000.0
# DQ learning path:  [4, 2, 0]
# dijkstra path:     [4, 2, 0]
# cost:         2000.0
# DQ learning path:  [5, 3, 0]
# dijkstra path:     [5, 3, 0]
# cost:         3000.0
# DQ learning path:  [6, 5, 3, 0]
# dijkstra path:     [6, 4, 2, 0]
# cost:         3000.0
# DQ learning path:  [7, 5, 3, 0]
# dijkstra path:     [7, 4, 2, 0]
# cost:         4000.0
# DQ learning path:  [8, 6, 5, 3, 0]
# dijkstra path:     [8, 6, 4, 2, 0]
# cost:         4000.0
# DQ learning path:  [9, 7, 5, 3, 0]
# dijkstra path:     [9, 7, 4, 2, 0]
# cost:         5000.0
# DQ learning path:  [10, 9, 7, 5, 3, 0]
# dijkstra path:     [10, 8, 6, 4, 2, 0]
# cost:         5000.0
# DQ learning path:  [11, 9, 7, 5, 3, 0]
# dijkstra path:     [11, 8, 6, 4, 2, 0]
# cost:         7000.0
# DQ learning path:  [12, 15, 17, 19, 6, 5, 3, 0]
# dijkstra path:     [12, 14, 16, 19, 6, 4, 2, 0]
# cost:         7000.0
# DQ learning path:  [13, 15, 17, 19, 6, 5, 3, 0]
# dijkstra path:     [13, 14, 16, 19, 6, 4, 2, 0]
# cost:         8000.0
# DQ learning path:  [14, 12, 15, 17, 19, 6, 5, 3, 0]
# dijkstra path:     [14, 16, 19, 6, 4, 2, 0]
# cost:         6000.0
# DQ learning path:  [15, 17, 19, 6, 5, 3, 0]
# dijkstra path:     [15, 17, 19, 6, 4, 2, 0]
# cost:         5000.0
# DQ learning path:  [16, 19, 6, 5, 3, 0]
# dijkstra path:     [16, 19, 6, 4, 2, 0]
# cost:         5000.0
# DQ learning path:  [17, 19, 6, 5, 3, 0]
# dijkstra path:     [17, 19, 6, 4, 2, 0]
# cost:         5000.0
# DQ learning path:  [18, 19, 6, 5, 3, 0]
# dijkstra path:     [18, 19, 6, 4, 2, 0]
# cost:         4000.0
# DQ learning path:  [19, 6, 5, 3, 0]
# dijkstra path:     [19, 6, 4, 2, 0]
# cost:         6000.0
# DQ learning path:  [20, 21, 19, 6, 5, 3, 0]
# dijkstra path:     [20, 18, 19, 6, 4, 2, 0]
# cost:         5000.0
# DQ learning path:  [21, 19, 6, 5, 3, 0]
# dijkstra path:     [21, 19, 6, 4, 2, 0]
# cost:         6000.0
# DQ learning path:  [22, 21, 19, 6, 5, 3, 0]
# dijkstra path:     [22, 21, 19, 6, 4, 2, 0]
# cost:         6000.0
# DQ learning path:  [23, 21, 19, 6, 5, 3, 0]
# dijkstra path:     [23, 21, 19, 6, 4, 2, 0]
# cost:         5000.0
# DQ learning path:  [24, 25, 6, 5, 3, 0]
# dijkstra path:     [24, 25, 6, 4, 2, 0]
# cost:         4000.0
# DQ learning path:  [25, 6, 5, 3, 0]
# dijkstra path:     [25, 6, 4, 2, 0]
# cost:         5000.0
# DQ learning path:  [26, 25, 6, 5, 3, 0]
# dijkstra path:     [26, 25, 6, 4, 2, 0]
# cost:         5000.0
# DQ learning path:  [27, 25, 6, 5, 3, 0]
# dijkstra path:     [27, 25, 6, 4, 2, 0]
# cost:         6000.0
# DQ learning path:  [28, 11, 9, 7, 5, 3, 0]
# dijkstra path:     [28, 10, 8, 6, 4, 2, 0]
# cost:         6000.0
# DQ learning path:  [29, 11, 9, 7, 5, 3, 0]
# dijkstra path:     [29, 10, 8, 6, 4, 2, 0]
# cost:         7000.0
# DQ learning path:  [30, 22, 21, 19, 6, 5, 3, 0]
# dijkstra path:     [30, 22, 21, 19, 6, 4, 2, 0]
# cost:         7000.0
# DQ learning path:  [31, 22, 21, 19, 6, 5, 3, 0]
# dijkstra path:     [31, 22, 21, 19, 6, 4, 2, 0]
# cost:         6000.0
# DQ learning path:  [32, 27, 25, 6, 5, 3, 0]
# dijkstra path:     [32, 26, 25, 6, 4, 2, 0]
# cost:         6000.0
# DQ learning path:  [33, 27, 25, 6, 5, 3, 0]
# dijkstra path:     [33, 26, 25, 6, 4, 2, 0]
# 100%|██████████████████████████████████████████████████████████████████████████████| 40/40 [00:33<00:00,  1.18it/s]
# cost:         2000.0
# DQ learning path:  [0, 2, 1]
# dijkstra path:     [0, 2, 1]
# cost:         1000.0
# DQ learning path:  [2, 1]
# dijkstra path:     [2, 1]
# cost:         1000.0
# DQ learning path:  [3, 1]
# dijkstra path:     [3, 1]
# cost:         2000.0
# DQ learning path:  [4, 2, 1]
# dijkstra path:     [4, 2, 1]
# cost:         2000.0
# DQ learning path:  [5, 3, 1]
# dijkstra path:     [5, 3, 1]
# cost:         3000.0
# DQ learning path:  [6, 4, 2, 1]
# dijkstra path:     [6, 4, 2, 1]
# cost:         3000.0
# DQ learning path:  [7, 4, 2, 1]
# dijkstra path:     [7, 4, 2, 1]
# cost:         4000.0
# DQ learning path:  [8, 6, 4, 2, 1]
# dijkstra path:     [8, 6, 4, 2, 1]
# cost:         4000.0
# DQ learning path:  [9, 7, 4, 2, 1]
# dijkstra path:     [9, 7, 4, 2, 1]
# cost:         5000.0
# DQ learning path:  [10, 9, 7, 4, 2, 1]
# dijkstra path:     [10, 8, 6, 4, 2, 1]
# cost:         5000.0
# DQ learning path:  [11, 9, 7, 4, 2, 1]
# dijkstra path:     [11, 8, 6, 4, 2, 1]
# cost:         7000.0
# DQ learning path:  [12, 15, 17, 19, 6, 4, 2, 1]
# dijkstra path:     [12, 14, 16, 19, 6, 4, 2, 1]
# cost:         7000.0
# DQ learning path:  [13, 15, 17, 19, 6, 4, 2, 1]
# dijkstra path:     [13, 14, 16, 19, 6, 4, 2, 1]
# cost:         6000.0
# DQ learning path:  [14, 16, 19, 6, 4, 2, 1]
# dijkstra path:     [14, 16, 19, 6, 4, 2, 1]
# cost:         6000.0
# DQ learning path:  [15, 17, 19, 6, 4, 2, 1]
# dijkstra path:     [15, 17, 19, 6, 4, 2, 1]
# cost:         5000.0
# DQ learning path:  [16, 19, 6, 4, 2, 1]
# dijkstra path:     [16, 19, 6, 4, 2, 1]
# cost:         5000.0
# DQ learning path:  [17, 19, 6, 4, 2, 1]
# dijkstra path:     [17, 19, 6, 4, 2, 1]
# cost:         5000.0
# DQ learning path:  [18, 19, 6, 4, 2, 1]
# dijkstra path:     [18, 19, 6, 4, 2, 1]
# cost:         4000.0
# DQ learning path:  [19, 6, 4, 2, 1]
# dijkstra path:     [19, 6, 4, 2, 1]
# cost:         6000.0
# DQ learning path:  [20, 21, 19, 6, 4, 2, 1]
# dijkstra path:     [20, 18, 19, 6, 4, 2, 1]
# cost:         5000.0
# DQ learning path:  [21, 19, 6, 4, 2, 1]
# dijkstra path:     [21, 19, 6, 4, 2, 1]
# cost:         6000.0
# DQ learning path:  [22, 21, 19, 6, 4, 2, 1]
# dijkstra path:     [22, 21, 19, 6, 4, 2, 1]
# cost:         6000.0
# DQ learning path:  [23, 21, 19, 6, 4, 2, 1]
# dijkstra path:     [23, 21, 19, 6, 4, 2, 1]
# cost:         5000.0
# DQ learning path:  [24, 25, 6, 4, 2, 1]
# dijkstra path:     [24, 25, 6, 4, 2, 1]
# cost:         4000.0
# DQ learning path:  [25, 6, 4, 2, 1]
# dijkstra path:     [25, 6, 4, 2, 1]
# cost:         5000.0
# DQ learning path:  [26, 25, 6, 4, 2, 1]
# dijkstra path:     [26, 25, 6, 4, 2, 1]
# cost:         5000.0
# DQ learning path:  [27, 25, 6, 4, 2, 1]
# dijkstra path:     [27, 25, 6, 4, 2, 1]
# cost:         6000.0
# DQ learning path:  [28, 10, 9, 7, 4, 2, 1]
# dijkstra path:     [28, 10, 8, 6, 4, 2, 1]
# cost:         6000.0
# DQ learning path:  [29, 10, 9, 7, 4, 2, 1]
# dijkstra path:     [29, 10, 8, 6, 4, 2, 1]
# cost:         7000.0
# DQ learning path:  [30, 22, 21, 19, 6, 4, 2, 1]
# dijkstra path:     [30, 22, 21, 19, 6, 4, 2, 1]
# cost:         7000.0
# DQ learning path:  [31, 22, 21, 19, 6, 4, 2, 1]
# dijkstra path:     [31, 22, 21, 19, 6, 4, 2, 1]
# cost:         6000.0
# DQ learning path:  [32, 26, 25, 6, 4, 2, 1]
# dijkstra path:     [32, 26, 25, 6, 4, 2, 1]
# cost:         6000.0
# DQ learning path:  [33, 26, 25, 6, 4, 2, 1]
# dijkstra path:     [33, 26, 25, 6, 4, 2, 1]
# 100%|██████████████████████████████████████████████████████████████████████████████| 40/40 [00:28<00:00,  1.38it/s]
# cost:         1000.0
# DQ learning path:  [0, 2]
# dijkstra path:     [0, 2]
# cost:         1000.0
# DQ learning path:  [1, 2]
# dijkstra path:     [1, 2]
# cost:         2000.0
# DQ learning path:  [3, 0, 2]
# dijkstra path:     [3, 0, 2]
# cost:         1000.0
# DQ learning path:  [4, 2]
# dijkstra path:     [4, 2]
# cost:         3000.0
# DQ learning path:  [5, 3, 0, 2]
# dijkstra path:     [5, 3, 0, 2]
# cost:         2000.0
# DQ learning path:  [6, 4, 2]
# dijkstra path:     [6, 4, 2]
# cost:         2000.0
# DQ learning path:  [7, 4, 2]
# dijkstra path:     [7, 4, 2]
# cost:         3000.0
# DQ learning path:  [8, 6, 4, 2]
# dijkstra path:     [8, 6, 4, 2]
# cost:         3000.0
# DQ learning path:  [9, 7, 4, 2]
# dijkstra path:     [9, 7, 4, 2]
# cost:         4000.0
# DQ learning path:  [10, 8, 6, 4, 2]
# dijkstra path:     [10, 8, 6, 4, 2]
# cost:         4000.0
# DQ learning path:  [11, 8, 6, 4, 2]
# dijkstra path:     [11, 8, 6, 4, 2]
# cost:         6000.0
# DQ learning path:  [12, 15, 17, 19, 6, 4, 2]
# dijkstra path:     [12, 14, 16, 19, 6, 4, 2]
# cost:         6000.0
# DQ learning path:  [13, 15, 17, 19, 6, 4, 2]
# dijkstra path:     [13, 14, 16, 19, 6, 4, 2]
# cost:         5000.0
# DQ learning path:  [14, 16, 19, 6, 4, 2]
# dijkstra path:     [14, 16, 19, 6, 4, 2]
# cost:         5000.0
# DQ learning path:  [15, 17, 19, 6, 4, 2]
# dijkstra path:     [15, 17, 19, 6, 4, 2]
# cost:         4000.0
# DQ learning path:  [16, 19, 6, 4, 2]
# dijkstra path:     [16, 19, 6, 4, 2]
# cost:         4000.0
# DQ learning path:  [17, 19, 6, 4, 2]
# dijkstra path:     [17, 19, 6, 4, 2]
# cost:         4000.0
# DQ learning path:  [18, 19, 6, 4, 2]
# dijkstra path:     [18, 19, 6, 4, 2]
# cost:         3000.0
# DQ learning path:  [19, 6, 4, 2]
# dijkstra path:     [19, 6, 4, 2]
# cost:         5000.0
# DQ learning path:  [20, 21, 19, 6, 4, 2]
# dijkstra path:     [20, 18, 19, 6, 4, 2]
# cost:         4000.0
# DQ learning path:  [21, 19, 6, 4, 2]
# dijkstra path:     [21, 19, 6, 4, 2]
# cost:         5000.0
# DQ learning path:  [22, 21, 19, 6, 4, 2]
# dijkstra path:     [22, 21, 19, 6, 4, 2]
# cost:         5000.0
# DQ learning path:  [23, 21, 19, 6, 4, 2]
# dijkstra path:     [23, 21, 19, 6, 4, 2]
# cost:         4000.0
# DQ learning path:  [24, 25, 6, 4, 2]
# dijkstra path:     [24, 25, 6, 4, 2]
# cost:         3000.0
# DQ learning path:  [25, 6, 4, 2]
# dijkstra path:     [25, 6, 4, 2]
# cost:         4000.0
# DQ learning path:  [26, 25, 6, 4, 2]
# dijkstra path:     [26, 25, 6, 4, 2]
# cost:         4000.0
# DQ learning path:  [27, 25, 6, 4, 2]
# dijkstra path:     [27, 25, 6, 4, 2]
# cost:         5000.0
# DQ learning path:  [28, 11, 8, 6, 4, 2]
# dijkstra path:     [28, 10, 8, 6, 4, 2]
# cost:         5000.0
# DQ learning path:  [29, 11, 8, 6, 4, 2]
# dijkstra path:     [29, 10, 8, 6, 4, 2]
# cost:         6000.0
# DQ learning path:  [30, 23, 21, 19, 6, 4, 2]
# dijkstra path:     [30, 22, 21, 19, 6, 4, 2]
# cost:         6000.0
# DQ learning path:  [31, 23, 21, 19, 6, 4, 2]
# dijkstra path:     [31, 22, 21, 19, 6, 4, 2]
# cost:         5000.0
# DQ learning path:  [32, 26, 25, 6, 4, 2]
# dijkstra path:     [32, 26, 25, 6, 4, 2]
# cost:         5000.0
# DQ learning path:  [33, 26, 25, 6, 4, 2]
# dijkstra path:     [33, 26, 25, 6, 4, 2]
# ---- 95.60946583747864 seconds
# "\nif reward_list:\n    x = [i+1 for i in range(iters)]\n    trainer.plot_learning_curve(x, reward_list)\n    path, cost = trainer.find_path(src, dest)\n    print('qlearning path: ', path, 'cost: ', cost)\nprint('dijkstra path:  ', nx.shortest_path(G, src, dest, weight='Bandwidth (Mbps)'))\n"

# %% [markdown]
# ### All src/dest combinations
# This did not work, no model can handle all the src and dest combinations

# %%
import importlib
import all_combinations.agent_one_hot
importlib.reload(all_combinations.agent_one_hot)
from all_combinations.agent_one_hot import *
import all_combinations.env_one_hot
importlib.reload(all_combinations.env_one_hot)
from all_combinations.env_one_hot import *

import time 

start_time = time.time()

env = CitizenBankEnv()
trainer = Agent(env, env.num_devices, 50, 50,   1000,        alpha=2.5e-5, batch_size=126,  max_iters =20, epsilon=1, \
                min_epsilon=0.03, steps_target=100, gamma=0.95)
trainer.train_combinations()
"""
if reward_list:
    x = [i+1 for i in range(iters)]
    trainer.plot_learning_curve(x, reward_list)
    path, cost = trainer.find_path(src, dest)
    print('qlearning path: ', path, 'cost: ', cost)
print('dijkstra path:  ', nx.shortest_path(G, src, dest, weight='Bandwidth (Mbps)'))
"""

path, cost = trainer.find_path(12, 1)
print(path)
print('cost: ', cost)

# %% [markdown]
# ### Only one src and dest
#
# Each src and dest will have a network model

# %%
import importlib
import src_dest.agent_one_hot_sd
importlib.reload(src_dest.agent_one_hot_sd)
from src_dest.agent_one_hot_sd import *
import src_dest.env_one_hot_sd
importlib.reload(src_dest.env_one_hot_sd)
from src_dest.env_one_hot_sd import *

env = CitizenBankEnv()
trainer = Agent(env, env.num_devices, 50, 50,10000,alpha=2.5e-3, batch_size=126, max_iters =200, epsilon=1, min_epsilon=0.03, steps_target=100, gamma=0.95)
state = [30,13]

trainer.train(state[0],state[1])
path, cost = trainer.find_path(state[0],state[1])
print('DeepQ path:     ', path, 'cost: ', cost)
print('dijkstra path:  ', nx.shortest_path(G, state[0], state[1], weight='Bandwidth (Mbps)'))
# Out:
# Initial state:  30
# Destination:  13
# [-27000.0, -5000.0, -5000.0, -5000.0, -5000.0, -340000.0, -340000.0, -295000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -7000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -7000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -7000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0, -5000.0]
# DeepQ path:      [30, 23, 20, 18, 17, 15, 13] cost:  6000.0
# dijkstra path:   [30, 22, 21, 19, 16, 14, 13]

# %% [markdown]
# ## Q Learning GNN

# %%
import importlib
import agent_gnn
importlib.reload(agent_gnn)
from agent_gnn import *

import env
importlib.reload(env)
from env import *

env = CitizenBankEnv()
print(env.num_devices)

trainer = Agent(env, env.num_devices, 20,       20,        30, 20, 10000,       alpha=2.5e-5, batch_size=236,  max_iters =200, epsilon=0.05, steps_target=500, gamma=0.95)
trainer.train()
"""
if reward_list:
    x = [i+1 for i in range(iters)]
    trainer.plot_learning_curve(x, reward_list)
    path, cost = trainer.find_path(src, dest)
    print('qlearning path: ', path, 'cost: ', cost)
print('dijkstra path:  ', nx.shortest_path(G, src, dest, weight='Bandwidth (Mbps)'))
"""

path, cost = trainer.find_path(0, 4)

print(path)
print('cost: ', cost)
# Out:
# 34
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In [2], line 14
#      11 print(env.num_devices)
#      13 trainer = Agent(env, env.num_devices, 20,       20,        30, 20, 10000,       alpha=2.5e-5, batch_size=236,  max_iters =200, epsilon=0.05, steps_target=500, gamma=0.95)
# ---> 14 trainer.train()
#      15 """
#      16 if reward_list:
#      17     x = [i+1 for i in range(iters)]
#    (...)
#      21 print('dijkstra path:  ', nx.shortest_path(G, src, dest, weight='Bandwidth (Mbps)'))
#      22 """
#      24 path, cost = trainer.find_path(0, 4)
#
# File ~/Projects/q-learning/CitizenBank/DeepQAction/agent_gnn.py:265, in Agent.train(self)
#     263 #Update the Q function
#     264 loss = self.loss_fun(q_targets,q_values)
# --> 265 loss.backward(retain_graph=True)
#     267 # Update weights
#     268 self.model.optimizer.step()
#
# File ~/opt/miniconda3/envs/M1Max/lib/python3.8/site-packages/torch/_tensor.py:396, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     387 if has_torch_function_unary(self):
#     388     return handle_torch_function(
#     389         Tensor.backward,
#     390         (self,),
#    (...)
#     394         create_graph=create_graph,
#     395         inputs=inputs)
# --> 396 torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#
# File ~/opt/miniconda3/envs/M1Max/lib/python3.8/site-packages/torch/autograd/__init__.py:173, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     168     retain_graph = create_graph
#     170 # The reason we repeat same the comment below is that
#     171 # some Python versions print out the first line of a multi-line function
#     172 # calls in the traceback and some print out the last line
# --> 173 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     174     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     175     allow_unreachable=True, accumulate_grad=True)
#
# RuntimeError: one of the variables needed for gradient computation has been modified by an inplace operation: [torch.FloatTensor [1, 1, 20]] is at version 1; expected version 0 instead. Hint: the backtrace further above shows the operation that failed to compute its gradient. The variable in question was changed in there or anywhere later. Good luck!

# %%
from torch_geometric.utils import to_networkx, from_networkx

src = 20
dest= 23
path, cost = trainer.find_path(src, dest)
G = to_networkx(env.graph)
print('DeepQ    path:  ', path)
print('cost: ', cost)

print('dijkstra path:  ', nx.shortest_path(G, src, dest))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 5
#       3 src = 20
#       4 dest= 23
# ----> 5 path, cost = trainer.find_path(src, dest)
#       6 G = to_networkx(env.graph)
#       7 print('DeepQ    path:  ', path)
#
# NameError: name 'trainer' is not defined

# %%
env.graph
# Out:
# Data(edge_index=[2, 112], num_nodes=34, x=[34, 34])

# %%
1000 / 60
# Out:
# 16.666666666666668
