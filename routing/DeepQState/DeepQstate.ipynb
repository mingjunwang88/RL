# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('links.csv')[['DeviceA_Code','DeviceB_Code']]
points_list = [(i,j) for i,j in df.values]

import networkx as nx
G=nx.Graph()
G.add_edges_from(points_list)
pos = nx.spring_layout(G)
nx.draw_networkx_nodes(G,pos)
nx.draw_networkx_edges(G,pos)
nx.draw_networkx_labels(G,pos)
plt.show()

# %%
import importlib
import agents_state
importlib.reload(agents_state)
from agents_state import *
import env
importlib.reload(env)
from env import *

env = CitizenBankEnv()
src = env.state
dest = env.dest
               #env, num_state,       dim_state,h1, h2, max_memsize, alpha=1e-4, batch_size=258, max_iters = 30, epsilon=0.05, steps_target=1000, gamma=0.99):
for alpha in [2.5e-4, 2.5e-5, 2.5e-6, 2.5e-7]:
    print('alpha: ',alpha )
    trainer = Agent(env, env.num_devices, 36,   30, 20, 10000,       alpha=alpha, batch_size=126,  max_iters =250, epsilon=0.05, steps_target=500, gamma=0.95)
    trainer.train()
"""
if reward_list:
    x = [i+1 for i in range(iters)]
    trainer.plot_learning_curve(x, reward_list)
    path, cost = trainer.find_path(src, dest)
    print('qlearning path: ', path, 'cost: ', cost)
print('dijkstra path:  ', nx.shortest_path(G, src, dest, weight='Bandwidth (Mbps)'))
"""

#path, cost = trainer.find_path(0, 4)
#print(path)
#print('cost: ', cost)
# Out:
# alpha:  0.00025
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [2], line 16
#      14     print('alpha: ',alpha )
#      15     trainer = Agent(env, env.num_devices, 36,   30, 20, 10000,       alpha=alpha, batch_size=126,  max_iters =250, epsilon=0.05, steps_target=500, gamma=0.95)
# ---> 16     trainer.train()
#      17 """
#      18 if reward_list:
#      19     x = [i+1 for i in range(iters)]
#    (...)
#      23 print('dijkstra path:  ', nx.shortest_path(G, src, dest, weight='Bandwidth (Mbps)'))
#      24 """
#
# File ~/Projects/q-learning/Pratice/DeepQState/agents_state.py:232, in Agent.train(self)
#     230 # Loss function
#     231 loss = self.loss_fun(q_targets,q_values)
# --> 232 loss.backward(retain_graph=True)
#     234 # Update weights
#     235 self.model.optimizer.step()
#
# File ~/opt/miniconda3/envs/M1Max/lib/python3.8/site-packages/torch/_tensor.py:396, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     387 if has_torch_function_unary(self):
#     388     return handle_torch_function(
#     389         Tensor.backward,
#     390         (self,),
#    (...)
#     394         create_graph=create_graph,
#     395         inputs=inputs)
# --> 396 torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#
# File ~/opt/miniconda3/envs/M1Max/lib/python3.8/site-packages/torch/autograd/__init__.py:173, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     168     retain_graph = create_graph
#     170 # The reason we repeat same the comment below is that
#     171 # some Python versions print out the first line of a multi-line function
#     172 # calls in the traceback and some print out the last line
# --> 173 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     174     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     175     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:

# %%
path, cost = trainer.find_path(10, 15)
print(path)
print('cost: ', cost)
# Out:
# No path found
# [10, 28, 11, 29, 15]
# cost:  3000.0

# %%
import gym
from gym.spaces import Box, Discrete

# %%
action_spaces = Box(-1, 1, shape=(10,))
action_spaces.sample()
# Out:
# array([-0.93956614,  0.35481822, -0.77239513,  0.11677177,  0.37774643,
#         0.66379607, -0.8354244 ,  0.06844016,  0.1576849 , -0.3403559 ],
#       dtype=float32)

# %%
action_spaces = Box(-1, 1, shape=(4,2))
action_spaces.sample()
# Out:
# array([[ 0.8374544 ,  0.7689311 ],
#        [-0.96916914, -0.8101031 ],
#        [ 0.02557393,  0.50489676],
#        [ 0.11491167, -0.6299545 ]], dtype=float32)

# %%
a = Box(low=np.array([-1.0, -2.0]), high=np.array([2.0, 4.0]), dtype=np.float32)
a.sample()
# Out:
# array([ 1.122372  , -0.18853071], dtype=float32)
